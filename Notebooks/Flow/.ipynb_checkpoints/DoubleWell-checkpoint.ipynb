# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent.parent); os.chdir(set_path)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
from TargetDistributions.DoubleWell import ManyWellEnergy
import torch
from FittedModels.utils.plotting_utils import plot_sampling_info, plot_divergences
torch.manual_seed(5)
from ImportanceSampling.VanillaImportanceSampler import VanillaImportanceSampling
from FittedModels.utils.plotting_utils import plot_distributions
from FittedModels.train import LearntDistributionManager
from Utils.plotting_utils import plot_distribution
from Utils.numerical_utils import quadratic_function as expectation_function
from FittedModels.Models.FlowModel import FlowModel
from FittedModels.utils.plotting_utils import plot_history
import matplotlib.pyplot as plt
from FittedModels.utils.plotting_utils import plot_samples_vs_contours_many_well as plot_samples_vs_contours
torch.set_default_dtype(torch.float64)

# %%
def plotter(*args, **kwargs):
    # wrap plotting function like this so it displays during training
    plot_samples_vs_contours(*args, **kwargs)
    plt.show()

# %%
target = ManyWellEnergy(2, a=-0.5, b=-6)
dist = plot_distribution(target, bounds=[[-3, 3], [-3, 3]], n_points=300)
plt.show()

# %% [markdown]
# # Alpha=2, no blocking nans and infs

# %%
torch.manual_seed(1)
# ******************* Parameters *******************
dim = 2
epochs = int(5e3)
n_samples_estimation = int(1e5)
batch_size = int(1e3)
lr = 1e-3
optimizer = "Adam"
loss_type = "DReG"  # "kl"  #
initial_flow_scaling = 2.0
n_flow_steps = 30
annealing = True
flow_type = "RealNVP"
n_plots = 10

# %%
torch.manual_seed(0)  # 0
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=n_flow_steps,
                           scaling_factor=initial_flow_scaling, flow_type=flow_type)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type=loss_type,
                                   lr=lr, optimizer=optimizer, annealing=annealing)

plot_samples_vs_contours(tester)
plt.show()
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

plot_distributions(tester, bounds=[[-3, 3], [-3, 3]], n_points=100)
plt.show()
history = tester.train(epochs, batch_size=batch_size, clip_grad_norm=True, max_grad_norm=1,
                       intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
plot_history(history)
plt.show()
plot_divergences(history)
plt.show()
plot_sampling_info(history)
plt.show()

expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n"
      f"effective sample size before is {info_before['effective_sample_size'] / n_samples_estimation}\n"
      f"effective sample size after train is {info['effective_sample_size'] / n_samples_estimation}\n"
      f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

plot_distributions(tester, bounds=[[-3, 3], [-3, 3]], n_points=100)
plt.show()
# Out:
# loss: -12.372653313804015, mean log p_x -27.021247349816573:   0%|                                                                                            | 0/5000 [00:00<?, ?it/s]
# loss: 13.996727336115516, mean log p_x 7.251142899829587:  10%|████████▍                                                                            | 499/5000 [00:52<07:15, 10.33it/s]
# loss: 13.996727336115516, mean log p_x 7.251142899829587:  10%|████████▌                                                                            | 503/5000 [00:53<12:49,  5.84it/s]
# ESS is 0.4170155431947353
# loss: -10.464005207767588, mean log p_x 7.993067159232811:  20%|████████████████▌                                                                  | 1000/5000 [01:48<06:29, 10.28it/s]
# loss: -10.464005207767588, mean log p_x 7.993067159232811:  20%|████████████████▋                                                                  | 1002/5000 [01:49<12:26,  5.36it/s]
# ESS is 0.5908241370654651
# loss: -10.379765103234483, mean log p_x 8.192574437211071:  30%|████████████████████████▉                                                          | 1500/5000 [02:39<05:42, 10.22it/s]
# loss: -10.379765103234483, mean log p_x 8.192574437211071:  30%|████████████████████████▉                                                          | 1502/5000 [02:40<11:00,  5.30it/s]
# ESS is 0.6769159465495186
# loss: -10.389172320620515, mean log p_x 8.19140342293693:  40%|█████████████████████████████████▍                                                  | 1989/5000 [03:30<04:35, 10.91it/s]
# Nan/Inf loss encountered
# loss: -10.350491942752386, mean log p_x 8.293878545145173:  40%|█████████████████████████████████▏                                                 | 1999/5000 [03:31<04:48, 10.40it/s]
# loss: -10.350491942752386, mean log p_x 8.293878545145173:  40%|█████████████████████████████████▏                                                 | 2002/5000 [03:32<09:06,  5.48it/s]
# ESS is 0.7322649994943444
# loss: -10.332583604931797, mean log p_x 8.425605869194504:  50%|█████████████████████████████████████████▍                                         | 2499/5000 [04:23<04:04, 10.22it/s]
# loss: -10.332583604931797, mean log p_x 8.425605869194504:  50%|█████████████████████████████████████████▌                                         | 2502/5000 [04:23<06:52,  6.06it/s]
# ESS is 0.7697774485061908
# loss: -10.324563966889858, mean log p_x 8.411718108658748:  60%|█████████████████████████████████████████████████▊                                 | 3000/5000 [05:17<03:13, 10.31it/s]
# loss: -10.324563966889858, mean log p_x 8.411718108658748:  60%|█████████████████████████████████████████████████▊                                 | 3002/5000 [05:18<06:13,  5.35it/s]
# ESS is 0.795333818895819
# loss: -10.323451437128533, mean log p_x 8.442117899654201:  62%|███████████████████████████████████████████████████▎                               | 3092/5000 [05:27<02:59, 10.60it/s]
# Nan/Inf loss encountered
# loss: -10.372817313831641, mean log p_x 8.41916785618016:  63%|█████████████████████████████████████████████████████                               | 3162/5000 [05:34<03:12,  9.56it/s]
# Nan/Inf loss encountered
# loss: -10.372817313831641, mean log p_x 8.41916785618016:  64%|█████████████████████████████████████████████████████▌                              | 3191/5000 [05:37<03:01,  9.99it/s]
# Nan/Inf loss encountered
# loss: -10.310606314450858, mean log p_x 8.416416599778028:  67%|███████████████████████████████████████████████████████▋                           | 3357/5000 [05:55<03:13,  8.51it/s]
# Nan/Inf loss encountered
# loss: -10.319284540389237, mean log p_x 8.3625536586869:  69%|██████████████████████████████████████████████████████████▋                          | 3453/5000 [06:05<03:08,  8.21it/s]
# Nan/Inf loss encountered
# loss: -10.315092744239251, mean log p_x 8.374087529469255:  70%|██████████████████████████████████████████████████████████                         | 3500/5000 [06:10<02:24, 10.35it/s]
# loss: -10.315092744239251, mean log p_x 8.374087529469255:  70%|██████████████████████████████████████████████████████████▏                        | 3502/5000 [06:11<04:18,  5.80it/s]
# ESS is 0.8133917749931817
# loss: -10.418084531580085, mean log p_x 8.4135441137618:  72%|█████████████████████████████████████████████████████████████▍                       | 3613/5000 [06:22<02:13, 10.41it/s]
# Nan/Inf loss encountered
# loss: -10.418084531580085, mean log p_x 8.4135441137618:  73%|█████████████████████████████████████████████████████████████▋                       | 3629/5000 [06:23<02:06, 10.80it/s]
# Nan/Inf loss encountered
# loss: -10.349615473530495, mean log p_x 8.361294550253747:  73%|████████████████████████████████████████████████████████████▊                      | 3667/5000 [06:27<02:04, 10.75it/s]
# Nan/Inf loss encountered
# loss: -10.349615473530495, mean log p_x 8.361294550253747:  74%|█████████████████████████████████████████████████████████████▏                     | 3685/5000 [06:29<02:01, 10.85it/s]
# Nan/Inf loss encountered
# loss: -10.349615473530495, mean log p_x 8.361294550253747:  74%|█████████████████████████████████████████████████████████████▎                     | 3695/5000 [06:30<01:58, 11.02it/s]
# Nan/Inf loss encountered
# loss: -10.31985745001181, mean log p_x 8.402557630770524:  74%|██████████████████████████████████████████████████████████████▏                     | 3703/5000 [06:31<02:30,  8.59it/s]
# Nan/Inf loss encountered
# loss: -10.31985745001181, mean log p_x 8.402557630770524:  75%|██████████████████████████████████████████████████████████████▋                     | 3733/5000 [06:34<01:54, 11.02it/s]
# Nan/Inf loss encountered
# loss: -10.319458887623153, mean log p_x 7.470226509342943:  75%|██████████████████████████████████████████████████████████████▌                    | 3770/5000 [06:38<01:57, 10.46it/s]
# Nan/Inf loss encountered
# loss: -10.319458887623153, mean log p_x 7.470226509342943:  76%|██████████████████████████████████████████████████████████████▉                    | 3790/5000 [06:40<01:53, 10.70it/s]
# Nan/Inf loss encountered
# loss: -10.319458887623153, mean log p_x 7.470226509342943:  76%|███████████████████████████████████████████████████████████████                    | 3798/5000 [06:40<01:51, 10.77it/s]
# Nan/Inf loss encountered
# loss: -10.368374919550675, mean log p_x 8.394694827592575:  76%|███████████████████████████████████████████████████████████████▏                   | 3808/5000 [06:42<02:04,  9.60it/s]
# Nan/Inf loss encountered
# loss: -10.368374919550675, mean log p_x 8.394694827592575:  76%|███████████████████████████████████████████████████████████████▍                   | 3824/5000 [06:43<02:00,  9.78it/s]
# Nan/Inf loss encountered
# loss: -10.345406385016396, mean log p_x 8.399411663778723:  77%|████████████████████████████████████████████████████████████████                   | 3862/5000 [06:47<01:57,  9.72it/s]
# Nan/Inf loss encountered
# loss: -10.345406385016396, mean log p_x 8.399411663778723:  78%|████████████████████████████████████████████████████████████████▍                  | 3880/5000 [06:49<01:44, 10.67it/s]
# Nan/Inf loss encountered
# loss: -10.325038007149399, mean log p_x 8.447074182531157:  80%|██████████████████████████████████████████████████████████████████▍                | 4000/5000 [07:02<01:46,  9.41it/s]
# loss: -10.325038007149399, mean log p_x 8.447074182531157:  80%|██████████████████████████████████████████████████████████████████▍                | 4002/5000 [07:03<04:14,  3.92it/s]
# ESS is nan
# loss: -10.314782220684606, mean log p_x 8.432693710220398:  81%|███████████████████████████████████████████████████████████████████▌               | 4070/5000 [07:10<01:33,  9.89it/s]
# Nan/Inf loss encountered
# loss: -10.314782220684606, mean log p_x 8.432693710220398:  82%|███████████████████████████████████████████████████████████████████▋               | 4081/5000 [07:11<01:26, 10.58it/s]
# Nan/Inf loss encountered
# loss: -10.321951657104222, mean log p_x 8.388131863357495:  82%|████████████████████████████████████████████████████████████████████▎              | 4117/5000 [07:15<01:23, 10.57it/s]
# Nan/Inf loss encountered
# loss: -10.321951657104222, mean log p_x 8.388131863357495:  83%|████████████████████████████████████████████████████████████████████▊              | 4147/5000 [07:18<01:16, 11.18it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: -10.321951657104222, mean log p_x 8.388131863357495:  83%|████████████████████████████████████████████████████████████████████▊              | 4149/5000 [07:18<01:14, 11.47it/s]
# Nan/Inf loss encountered
# loss: -10.34716043674597, mean log p_x 8.444049530803488:  84%|██████████████████████████████████████████████████████████████████████▏             | 4175/5000 [07:21<01:17, 10.68it/s]
# Nan/Inf loss encountered
# loss: -10.34716043674597, mean log p_x 8.444049530803488:  84%|██████████████████████████████████████████████████████████████████████▏             | 4179/5000 [07:21<01:16, 10.72it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: -10.34716043674597, mean log p_x 8.444049530803488:  84%|██████████████████████████████████████████████████████████████████████▎             | 4187/5000 [07:22<01:15, 10.76it/s]
# Nan/Inf loss encountered
# loss: -10.328164785754833, mean log p_x 8.38099447474003:  84%|██████████████████████████████████████████████████████████████████████▋             | 4209/5000 [07:24<01:25,  9.30it/s]
# Nan/Inf loss encountered
# loss: -10.328164785754833, mean log p_x 8.38099447474003:  85%|███████████████████████████████████████████████████████████████████████             | 4231/5000 [07:26<01:10, 10.87it/s]
# Nan/Inf loss encountered
# loss: -10.328164785754833, mean log p_x 8.38099447474003:  85%|███████████████████████████████████████████████████████████████████████▍            | 4249/5000 [07:28<01:11, 10.57it/s]
# Nan/Inf loss encountered
# loss: -10.398180155103642, mean log p_x 8.32017076473789:  85%|███████████████████████████████████████████████████████████████████████▌            | 4259/5000 [07:30<01:16,  9.69it/s]
# Nan/Inf loss encountered
# loss: -10.398180155103642, mean log p_x 8.32017076473789:  85%|███████████████████████████████████████████████████████████████████████▋            | 4266/5000 [07:30<01:11, 10.29it/s]
# Nan/Inf loss encountered
# loss: -10.398180155103642, mean log p_x 8.32017076473789:  85%|███████████████████████████████████████████████████████████████████████▋            | 4268/5000 [07:30<01:07, 10.77it/s]
# Nan/Inf loss encountered
# loss: -10.329651242300304, mean log p_x 8.405545510185824:  87%|███████████████████████████████████████████████████████████████████████▊           | 4326/5000 [07:36<01:02, 10.86it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: -10.329651242300304, mean log p_x 8.405545510185824:  87%|████████████████████████████████████████████████████████████████████████▏          | 4346/5000 [07:38<01:03, 10.25it/s]
# Nan/Inf loss encountered
# loss: -10.30988361212773, mean log p_x 8.43785573153134:  87%|██████████████████████████████████████████████████████████████████████████           | 4360/5000 [07:40<01:04,  9.97it/s]
# Nan/Inf loss encountered
# loss: -10.30988361212773, mean log p_x 8.43785573153134:  88%|██████████████████████████████████████████████████████████████████████████▌          | 4386/5000 [07:43<01:01,  9.98it/s]
# Nan/Inf loss encountered
# loss: -10.30988361212773, mean log p_x 8.43785573153134:  88%|██████████████████████████████████████████████████████████████████████████▊          | 4399/5000 [07:44<00:57, 10.46it/s]
# Nan/Inf loss encountered
# loss: -10.307672189874346, mean log p_x 8.433317433960067:  89%|█████████████████████████████████████████████████████████████████████████▉         | 4457/5000 [07:50<01:06,  8.15it/s]
# Nan/Inf loss encountered
# loss: -10.307672189874346, mean log p_x 8.433317433960067:  89%|██████████████████████████████████████████████████████████████████████████         | 4459/5000 [07:50<00:59,  9.07it/s]
# Nan/Inf loss encountered
# loss: -10.307672189874346, mean log p_x 8.433317433960067:  89%|██████████████████████████████████████████████████████████████████████████▏        | 4467/5000 [07:51<00:49, 10.82it/s]
# Nan/Inf loss encountered
# loss: -10.325350449065043, mean log p_x 8.378417954868217:  90%|██████████████████████████████████████████████████████████████████████████▋        | 4500/5000 [07:55<01:02,  8.00it/s]
# loss: -10.325350449065043, mean log p_x 8.378417954868217:  90%|██████████████████████████████████████████████████████████████████████████▋        | 4502/5000 [07:56<02:11,  3.80it/s]
# ESS is nan
# loss: -10.310602873846875, mean log p_x 8.455700584660729:  93%|████████████████████████████████████████████████████████████████████████████▉      | 4635/5000 [08:09<00:35, 10.42it/s]
# Nan/Inf loss encountered
# loss: -10.309230522125869, mean log p_x 8.345261934535031:  93%|█████████████████████████████████████████████████████████████████████████████▎     | 4654/5000 [08:11<00:39,  8.83it/s]
# Nan/Inf loss encountered
# loss: -10.309230522125869, mean log p_x 8.345261934535031:  93%|█████████████████████████████████████████████████████████████████████████████▌     | 4669/5000 [08:13<00:31, 10.67it/s]
# Nan/Inf loss encountered
# loss: -10.315631515195841, mean log p_x 8.428670404423606:  95%|██████████████████████████████████████████████████████████████████████████████▌    | 4729/5000 [08:19<00:25, 10.71it/s]
# Nan/Inf loss encountered
# loss: -10.329476379796075, mean log p_x 7.839894559830038:  96%|███████████████████████████████████████████████████████████████████████████████▋   | 4799/5000 [08:26<00:19, 10.35it/s]
# Nan/Inf loss encountered
# loss: -10.329476379796075, mean log p_x 7.839894559830038:  97%|████████████████████████████████████████████████████████████████████████████████▏  | 4833/5000 [08:30<00:15, 10.77it/s]
# Nan/Inf loss encountered
# loss: -10.329476379796075, mean log p_x 7.839894559830038:  97%|████████████████████████████████████████████████████████████████████████████████▍  | 4849/5000 [08:31<00:14, 10.64it/s]
# Nan/Inf loss encountered
# loss: -10.324203849696053, mean log p_x 8.46484489404856:  97%|█████████████████████████████████████████████████████████████████████████████████▊  | 4872/5000 [08:34<00:12, 10.43it/s]
# Nan/Inf loss encountered
# loss: -10.301246677640359, mean log p_x 8.423920447315545:  98%|█████████████████████████████████████████████████████████████████████████████████▍ | 4906/5000 [08:37<00:10,  9.11it/s]
# Nan/Inf loss encountered
# loss: -10.301246677640359, mean log p_x 8.423920447315545:  99%|██████████████████████████████████████████████████████████████████████████████████ | 4943/5000 [08:41<00:05, 10.59it/s]
# Nan/Inf loss encountered
# loss: -10.301246677640359, mean log p_x 8.423920447315545:  99%|██████████████████████████████████████████████████████████████████████████████████▏| 4949/5000 [08:42<00:04, 10.76it/s]
# Nan/Inf loss encountered
# loss: -10.325966510988307, mean log p_x 8.336251381243809: 100%|███████████████████████████████████████████████████████████████████████████████████| 5000/5000 [08:47<00:00,  9.48it/s]
# NaN encountered in loss history
# NaN encountered in log_p_x history
# NaN encountered in log_q_x history
# NaN encountered in kl history
# NaN encountered in alpha_2_divergence history
# NaN encountered in importance_weights_var history
# NaN encountered in normalised_importance_weights_var history
# NaN encountered in effective_sample_size history
# estimate before training is 12.84542729070877
# estimate after training is 13.046105665001686
# effective sample size before is 0.09021921428432197
# effective sample size after train is 0.9471266934940388
# variance in weights is 5.580663034289012e-12

# %% [markdown]
# # Alpha=2

# %%
torch.manual_seed(1)
# ******************* Parameters *******************
dim = 2
epochs = int(5e3)
n_samples_estimation = int(1e5)
batch_size = int(1e3)
lr = 1e-3
optimizer = "Adam"
loss_type = "DReG"  # "kl"  #
initial_flow_scaling = 2.0
n_flow_steps = 30
annealing = True
flow_type = "RealNVP"
n_plots = 10

# %%
torch.manual_seed(0)  # 0
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=n_flow_steps,
                           scaling_factor=initial_flow_scaling, flow_type=flow_type)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type=loss_type,
                                   lr=lr, optimizer=optimizer, annealing=annealing)

plot_samples_vs_contours(tester)
plt.show()
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

plot_distributions(tester, bounds=[[-3, 3], [-3, 3]], n_points=100)
plt.show()
history = tester.train(epochs, batch_size=batch_size, clip_grad_norm=True, max_grad_norm=1,
                       intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
plot_history(history)
plt.show()
plot_divergences(history)
plt.show()
plot_sampling_info(history)
plt.show()

expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n"
      f"effective sample size before is {info_before['effective_sample_size'] / n_samples_estimation}\n"
      f"effective sample size after train is {info['effective_sample_size'] / n_samples_estimation}\n"
      f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

plot_distributions(tester, bounds=[[-3, 3], [-3, 3]], n_points=100)
plt.show()
# Out:
# loss: -12.372653313804015, mean log p_x -27.021247349816573:   0%|                                                                                            | 0/5000 [00:00<?, ?it/s]
# loss: 13.996727336115516, mean log p_x 7.251142899829587:  10%|████████▍                                                                            | 499/5000 [00:52<07:15, 10.33it/s]
# loss: 13.996727336115516, mean log p_x 7.251142899829587:  10%|████████▌                                                                            | 503/5000 [00:53<12:49,  5.84it/s]
# ESS is 0.4170155431947353
# loss: -10.464005207767588, mean log p_x 7.993067159232811:  20%|████████████████▌                                                                  | 1000/5000 [01:48<06:29, 10.28it/s]
# loss: -10.464005207767588, mean log p_x 7.993067159232811:  20%|████████████████▋                                                                  | 1002/5000 [01:49<12:26,  5.36it/s]
# ESS is 0.5908241370654651
# loss: -10.379765103234483, mean log p_x 8.192574437211071:  30%|████████████████████████▉                                                          | 1500/5000 [02:39<05:42, 10.22it/s]
# loss: -10.379765103234483, mean log p_x 8.192574437211071:  30%|████████████████████████▉                                                          | 1502/5000 [02:40<11:00,  5.30it/s]
# ESS is 0.6769159465495186
# loss: -10.389172320620515, mean log p_x 8.19140342293693:  40%|█████████████████████████████████▍                                                  | 1989/5000 [03:30<04:35, 10.91it/s]
# Nan/Inf loss encountered
# loss: -10.350491942752386, mean log p_x 8.293878545145173:  40%|█████████████████████████████████▏                                                 | 1999/5000 [03:31<04:48, 10.40it/s]
# loss: -10.350491942752386, mean log p_x 8.293878545145173:  40%|█████████████████████████████████▏                                                 | 2002/5000 [03:32<09:06,  5.48it/s]
# ESS is 0.7322649994943444
# loss: -10.332583604931797, mean log p_x 8.425605869194504:  50%|█████████████████████████████████████████▍                                         | 2499/5000 [04:23<04:04, 10.22it/s]
# loss: -10.332583604931797, mean log p_x 8.425605869194504:  50%|█████████████████████████████████████████▌                                         | 2502/5000 [04:23<06:52,  6.06it/s]
# ESS is 0.7697774485061908
# loss: -10.324563966889858, mean log p_x 8.411718108658748:  60%|█████████████████████████████████████████████████▊                                 | 3000/5000 [05:17<03:13, 10.31it/s]
# loss: -10.324563966889858, mean log p_x 8.411718108658748:  60%|█████████████████████████████████████████████████▊                                 | 3002/5000 [05:18<06:13,  5.35it/s]
# ESS is 0.795333818895819
# loss: -10.323451437128533, mean log p_x 8.442117899654201:  62%|███████████████████████████████████████████████████▎                               | 3092/5000 [05:27<02:59, 10.60it/s]
# Nan/Inf loss encountered
# loss: -10.372817313831641, mean log p_x 8.41916785618016:  63%|█████████████████████████████████████████████████████                               | 3162/5000 [05:34<03:12,  9.56it/s]
# Nan/Inf loss encountered
# loss: -10.372817313831641, mean log p_x 8.41916785618016:  64%|█████████████████████████████████████████████████████▌                              | 3191/5000 [05:37<03:01,  9.99it/s]
# Nan/Inf loss encountered
# loss: -10.310606314450858, mean log p_x 8.416416599778028:  67%|███████████████████████████████████████████████████████▋                           | 3357/5000 [05:55<03:13,  8.51it/s]
# Nan/Inf loss encountered
# loss: -10.319284540389237, mean log p_x 8.3625536586869:  69%|██████████████████████████████████████████████████████████▋                          | 3453/5000 [06:05<03:08,  8.21it/s]
# Nan/Inf loss encountered
# loss: -10.315092744239251, mean log p_x 8.374087529469255:  70%|██████████████████████████████████████████████████████████                         | 3500/5000 [06:10<02:24, 10.35it/s]
# loss: -10.315092744239251, mean log p_x 8.374087529469255:  70%|██████████████████████████████████████████████████████████▏                        | 3502/5000 [06:11<04:18,  5.80it/s]
# ESS is 0.8133917749931817
# loss: -10.418084531580085, mean log p_x 8.4135441137618:  72%|█████████████████████████████████████████████████████████████▍                       | 3613/5000 [06:22<02:13, 10.41it/s]
# Nan/Inf loss encountered
# loss: -10.418084531580085, mean log p_x 8.4135441137618:  73%|█████████████████████████████████████████████████████████████▋                       | 3629/5000 [06:23<02:06, 10.80it/s]
# Nan/Inf loss encountered
# loss: -10.349615473530495, mean log p_x 8.361294550253747:  73%|████████████████████████████████████████████████████████████▊                      | 3667/5000 [06:27<02:04, 10.75it/s]
# Nan/Inf loss encountered
# loss: -10.349615473530495, mean log p_x 8.361294550253747:  74%|█████████████████████████████████████████████████████████████▏                     | 3685/5000 [06:29<02:01, 10.85it/s]
# Nan/Inf loss encountered
# loss: -10.349615473530495, mean log p_x 8.361294550253747:  74%|█████████████████████████████████████████████████████████████▎                     | 3695/5000 [06:30<01:58, 11.02it/s]
# Nan/Inf loss encountered
# loss: -10.31985745001181, mean log p_x 8.402557630770524:  74%|██████████████████████████████████████████████████████████████▏                     | 3703/5000 [06:31<02:30,  8.59it/s]
# Nan/Inf loss encountered
# loss: -10.31985745001181, mean log p_x 8.402557630770524:  75%|██████████████████████████████████████████████████████████████▋                     | 3733/5000 [06:34<01:54, 11.02it/s]
# Nan/Inf loss encountered
# loss: -10.319458887623153, mean log p_x 7.470226509342943:  75%|██████████████████████████████████████████████████████████████▌                    | 3770/5000 [06:38<01:57, 10.46it/s]
# Nan/Inf loss encountered
# loss: -10.319458887623153, mean log p_x 7.470226509342943:  76%|██████████████████████████████████████████████████████████████▉                    | 3790/5000 [06:40<01:53, 10.70it/s]
# Nan/Inf loss encountered
# loss: -10.319458887623153, mean log p_x 7.470226509342943:  76%|███████████████████████████████████████████████████████████████                    | 3798/5000 [06:40<01:51, 10.77it/s]
# Nan/Inf loss encountered
# loss: -10.368374919550675, mean log p_x 8.394694827592575:  76%|███████████████████████████████████████████████████████████████▏                   | 3808/5000 [06:42<02:04,  9.60it/s]
# Nan/Inf loss encountered
# loss: -10.368374919550675, mean log p_x 8.394694827592575:  76%|███████████████████████████████████████████████████████████████▍                   | 3824/5000 [06:43<02:00,  9.78it/s]
# Nan/Inf loss encountered
# loss: -10.345406385016396, mean log p_x 8.399411663778723:  77%|████████████████████████████████████████████████████████████████                   | 3862/5000 [06:47<01:57,  9.72it/s]
# Nan/Inf loss encountered
# loss: -10.345406385016396, mean log p_x 8.399411663778723:  78%|████████████████████████████████████████████████████████████████▍                  | 3880/5000 [06:49<01:44, 10.67it/s]
# Nan/Inf loss encountered
# loss: -10.325038007149399, mean log p_x 8.447074182531157:  80%|██████████████████████████████████████████████████████████████████▍                | 4000/5000 [07:02<01:46,  9.41it/s]
# loss: -10.325038007149399, mean log p_x 8.447074182531157:  80%|██████████████████████████████████████████████████████████████████▍                | 4002/5000 [07:03<04:14,  3.92it/s]
# ESS is nan
# loss: -10.314782220684606, mean log p_x 8.432693710220398:  81%|███████████████████████████████████████████████████████████████████▌               | 4070/5000 [07:10<01:33,  9.89it/s]
# Nan/Inf loss encountered
# loss: -10.314782220684606, mean log p_x 8.432693710220398:  82%|███████████████████████████████████████████████████████████████████▋               | 4081/5000 [07:11<01:26, 10.58it/s]
# Nan/Inf loss encountered
# loss: -10.321951657104222, mean log p_x 8.388131863357495:  82%|████████████████████████████████████████████████████████████████████▎              | 4117/5000 [07:15<01:23, 10.57it/s]
# Nan/Inf loss encountered
# loss: -10.321951657104222, mean log p_x 8.388131863357495:  83%|████████████████████████████████████████████████████████████████████▊              | 4147/5000 [07:18<01:16, 11.18it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: -10.321951657104222, mean log p_x 8.388131863357495:  83%|████████████████████████████████████████████████████████████████████▊              | 4149/5000 [07:18<01:14, 11.47it/s]
# Nan/Inf loss encountered
# loss: -10.34716043674597, mean log p_x 8.444049530803488:  84%|██████████████████████████████████████████████████████████████████████▏             | 4175/5000 [07:21<01:17, 10.68it/s]
# Nan/Inf loss encountered
# loss: -10.34716043674597, mean log p_x 8.444049530803488:  84%|██████████████████████████████████████████████████████████████████████▏             | 4179/5000 [07:21<01:16, 10.72it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: -10.34716043674597, mean log p_x 8.444049530803488:  84%|██████████████████████████████████████████████████████████████████████▎             | 4187/5000 [07:22<01:15, 10.76it/s]
# Nan/Inf loss encountered
# loss: -10.328164785754833, mean log p_x 8.38099447474003:  84%|██████████████████████████████████████████████████████████████████████▋             | 4209/5000 [07:24<01:25,  9.30it/s]
# Nan/Inf loss encountered
# loss: -10.328164785754833, mean log p_x 8.38099447474003:  85%|███████████████████████████████████████████████████████████████████████             | 4231/5000 [07:26<01:10, 10.87it/s]
# Nan/Inf loss encountered
# loss: -10.328164785754833, mean log p_x 8.38099447474003:  85%|███████████████████████████████████████████████████████████████████████▍            | 4249/5000 [07:28<01:11, 10.57it/s]
# Nan/Inf loss encountered
# loss: -10.398180155103642, mean log p_x 8.32017076473789:  85%|███████████████████████████████████████████████████████████████████████▌            | 4259/5000 [07:30<01:16,  9.69it/s]
# Nan/Inf loss encountered
# loss: -10.398180155103642, mean log p_x 8.32017076473789:  85%|███████████████████████████████████████████████████████████████████████▋            | 4266/5000 [07:30<01:11, 10.29it/s]
# Nan/Inf loss encountered
# loss: -10.398180155103642, mean log p_x 8.32017076473789:  85%|███████████████████████████████████████████████████████████████████████▋            | 4268/5000 [07:30<01:07, 10.77it/s]
# Nan/Inf loss encountered
# loss: -10.329651242300304, mean log p_x 8.405545510185824:  87%|███████████████████████████████████████████████████████████████████████▊           | 4326/5000 [07:36<01:02, 10.86it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: -10.329651242300304, mean log p_x 8.405545510185824:  87%|████████████████████████████████████████████████████████████████████████▏          | 4346/5000 [07:38<01:03, 10.25it/s]
# Nan/Inf loss encountered
# loss: -10.30988361212773, mean log p_x 8.43785573153134:  87%|██████████████████████████████████████████████████████████████████████████           | 4360/5000 [07:40<01:04,  9.97it/s]
# Nan/Inf loss encountered
# loss: -10.30988361212773, mean log p_x 8.43785573153134:  88%|██████████████████████████████████████████████████████████████████████████▌          | 4386/5000 [07:43<01:01,  9.98it/s]
# Nan/Inf loss encountered
# loss: -10.30988361212773, mean log p_x 8.43785573153134:  88%|██████████████████████████████████████████████████████████████████████████▊          | 4399/5000 [07:44<00:57, 10.46it/s]
# Nan/Inf loss encountered
# loss: -10.307672189874346, mean log p_x 8.433317433960067:  89%|█████████████████████████████████████████████████████████████████████████▉         | 4457/5000 [07:50<01:06,  8.15it/s]
# Nan/Inf loss encountered
# loss: -10.307672189874346, mean log p_x 8.433317433960067:  89%|██████████████████████████████████████████████████████████████████████████         | 4459/5000 [07:50<00:59,  9.07it/s]
# Nan/Inf loss encountered
# loss: -10.307672189874346, mean log p_x 8.433317433960067:  89%|██████████████████████████████████████████████████████████████████████████▏        | 4467/5000 [07:51<00:49, 10.82it/s]
# Nan/Inf loss encountered
# loss: -10.325350449065043, mean log p_x 8.378417954868217:  90%|██████████████████████████████████████████████████████████████████████████▋        | 4500/5000 [07:55<01:02,  8.00it/s]
# loss: -10.325350449065043, mean log p_x 8.378417954868217:  90%|██████████████████████████████████████████████████████████████████████████▋        | 4502/5000 [07:56<02:11,  3.80it/s]
# ESS is nan
# loss: -10.310602873846875, mean log p_x 8.455700584660729:  93%|████████████████████████████████████████████████████████████████████████████▉      | 4635/5000 [08:09<00:35, 10.42it/s]
# Nan/Inf loss encountered
# loss: -10.309230522125869, mean log p_x 8.345261934535031:  93%|█████████████████████████████████████████████████████████████████████████████▎     | 4654/5000 [08:11<00:39,  8.83it/s]
# Nan/Inf loss encountered
# loss: -10.309230522125869, mean log p_x 8.345261934535031:  93%|█████████████████████████████████████████████████████████████████████████████▌     | 4669/5000 [08:13<00:31, 10.67it/s]
# Nan/Inf loss encountered
# loss: -10.315631515195841, mean log p_x 8.428670404423606:  95%|██████████████████████████████████████████████████████████████████████████████▌    | 4729/5000 [08:19<00:25, 10.71it/s]
# Nan/Inf loss encountered
# loss: -10.329476379796075, mean log p_x 7.839894559830038:  96%|███████████████████████████████████████████████████████████████████████████████▋   | 4799/5000 [08:26<00:19, 10.35it/s]
# Nan/Inf loss encountered
# loss: -10.329476379796075, mean log p_x 7.839894559830038:  97%|████████████████████████████████████████████████████████████████████████████████▏  | 4833/5000 [08:30<00:15, 10.77it/s]
# Nan/Inf loss encountered
# loss: -10.329476379796075, mean log p_x 7.839894559830038:  97%|████████████████████████████████████████████████████████████████████████████████▍  | 4849/5000 [08:31<00:14, 10.64it/s]
# Nan/Inf loss encountered
# loss: -10.324203849696053, mean log p_x 8.46484489404856:  97%|█████████████████████████████████████████████████████████████████████████████████▊  | 4872/5000 [08:34<00:12, 10.43it/s]
# Nan/Inf loss encountered
# loss: -10.301246677640359, mean log p_x 8.423920447315545:  98%|█████████████████████████████████████████████████████████████████████████████████▍ | 4906/5000 [08:37<00:10,  9.11it/s]
# Nan/Inf loss encountered
# loss: -10.301246677640359, mean log p_x 8.423920447315545:  99%|██████████████████████████████████████████████████████████████████████████████████ | 4943/5000 [08:41<00:05, 10.59it/s]
# Nan/Inf loss encountered
# loss: -10.301246677640359, mean log p_x 8.423920447315545:  99%|██████████████████████████████████████████████████████████████████████████████████▏| 4949/5000 [08:42<00:04, 10.76it/s]
# Nan/Inf loss encountered
# loss: -10.325966510988307, mean log p_x 8.336251381243809: 100%|███████████████████████████████████████████████████████████████████████████████████| 5000/5000 [08:47<00:00,  9.48it/s]
# NaN encountered in loss history
# NaN encountered in log_p_x history
# NaN encountered in log_q_x history
# NaN encountered in kl history
# NaN encountered in alpha_2_divergence history
# NaN encountered in importance_weights_var history
# NaN encountered in normalised_importance_weights_var history
# NaN encountered in effective_sample_size history
# estimate before training is 12.84542729070877
# estimate after training is 13.046105665001686
# effective sample size before is 0.09021921428432197
# effective sample size after train is 0.9471266934940388
# variance in weights is 5.580663034289012e-12

# %% [markdown]
# # KL

# %%
torch.manual_seed(1)
# ******************* Parameters *******************
dim = 2
epochs = int(1e4)
n_samples_estimation = int(1e5)
batch_size = int(1e3)
lr = 1e-3
optimizer = "Adam"
loss_type = "kl"
initial_flow_scaling = 2.0
n_flow_steps = 30
annealing = True
flow_type = "RealNVP"
n_plots = 10
def plotter(*args, **kwargs):
    # wrap plotting function like this so it displays during training
    plot_samples_vs_contours(*args, **kwargs)
    plt.show()

torch.manual_seed(0)  # 0
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=n_flow_steps,
                           scaling_factor=initial_flow_scaling, flow_type=flow_type)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type=loss_type,
                                   lr=lr, optimizer=optimizer, annealing=annealing)

plot_samples_vs_contours(tester)
plt.show()
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

plot_distributions(tester, bounds=[[-3, 3], [-3, 3]], n_points=100)
plt.show()
history = tester.train(epochs, batch_size=batch_size, clip_grad_norm=True, max_grad_norm=1,
                       intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
plot_history(history)
plt.show()
plot_divergences(history)
plt.show()
plot_sampling_info(history)
plt.show()

expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n"
      f"effective sample size before is {info_before['effective_sample_size'] / n_samples_estimation}\n"
      f"effective sample size after train is {info['effective_sample_size'] / n_samples_estimation}\n"
      f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
