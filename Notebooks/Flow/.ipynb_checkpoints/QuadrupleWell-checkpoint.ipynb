# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent.parent); os.chdir(set_path)

# %%
from TargetDistributions.DoubleWell import QuadrupleWellEnergy
import torch
from FittedModels.utils.plotting_utils import plot_sampling_info, plot_divergences
torch.manual_seed(5)
from ImportanceSampling.VanillaImportanceSampler import VanillaImportanceSampling
from FittedModels.train import LearntDistributionManager
from Utils.numerical_utils import quadratic_function as expectation_function
from FittedModels.Models.FlowModel import FlowModel
from FittedModels.utils.plotting_utils import plot_history
import matplotlib.pyplot as plt
from FittedModels.utils.plotting_utils import plot_samples_vs_contours_quadruple_well

# %%
def plotter(*args, **kwargs):
    # wrap plotting function like this so it displays during training
    plot_samples_vs_contours_quadruple_well(*args, **kwargs)
    plt.show()

# %%
target = QuadrupleWellEnergy(a=-0.5, b=-6)

# %% [markdown]
# # KL

# %%
torch.manual_seed(1)
torch.set_default_dtype(torch.float64)
# ******************* Parameters *******************
dim = 4
epochs = int(1e4)
n_samples_estimation = int(1e5)
batch_size = int(512)
lr = 1e-4
train_prior = False
weight_decay = 1e-6
clip_grad_norm = False
optimizer = "Adamax"
flow_type = "RealNVP"
loss_type = "kl"
initial_flow_scaling = 1.5
n_flow_steps = 64
annealing = True
n_plots = 20

# %%
torch.manual_seed(0)  # 0
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=n_flow_steps,
                           scaling_factor=initial_flow_scaling, flow_type=flow_type)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type=loss_type,
                                   lr=lr, optimizer=optimizer, annealing=annealing, weight_decay=weight_decay)

plotter(tester)
plt.show()
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

if train_prior:
    history_prior = tester.train_prior(epochs=200, batch_size=batch_size, lr=5e-3)
    plot_history(history_prior)
    plt.show()
    plotter(tester)
    plt.show()
    expectation_prior_trained, info_prior = tester.estimate_expectation(n_samples_estimation, expectation_function)


history = tester.train(epochs, batch_size=batch_size, clip_grad_norm=clip_grad_norm, max_grad_norm=1,
                       intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
plot_history(history)
plt.show()
plot_divergences(history)
plt.show()
plot_sampling_info(history)
plt.show()

expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n"
      f"effective sample size before is {info_before['effective_sample_size'] / n_samples_estimation}\n"
      f"effective sample size after train is {info['effective_sample_size'] / n_samples_estimation}\n"
      f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

if train_prior:
    print(f"estimate after prior training is {expectation_prior_trained} \n"
        f"effective sample size trained prior is {info_prior['effective_sample_size'] / n_samples_estimation}\n")

plotter(tester, n_samples=1000)
plt.show()
# Out:
# loss: -7.282124399316137, mean log p_x -8.604772276691133:   0%|          | 0/10000 [00:00<?, ?it/s]
# loss: -8.875009695867497, mean log p_x -33.15416338394846:   2%|▏         | 159/10000 [00:51<45:36,  3.60it/s]
# Nan/Inf loss encountered
# loss: -6.985010876146405, mean log p_x -67.78803398652266:   2%|▏         | 220/10000 [01:10<45:43,  3.56it/s]
# Nan/Inf loss encountered
# loss: -6.0575621645589255, mean log p_x -35.20273530733253:   5%|▌         | 500/10000 [02:39<49:12,  3.22it/s]
# loss: -6.045094159645578, mean log p_x -27.99764885417114:   7%|▋         | 674/10000 [03:35<46:16,  3.36it/s]
# Nan/Inf loss encountered
# loss: -5.9499072199955965, mean log p_x -24.563700634075403:   7%|▋         | 736/10000 [03:54<43:30,  3.55it/s]
# Nan/Inf loss encountered
# loss: -1.8977257537976067, mean log p_x -41.68506295815257:  10%|▉         | 977/10000 [05:10<41:17,  3.64it/s]
# Nan/Inf loss encountered
# loss: -1.8977257537976067, mean log p_x -41.68506295815257:  10%|▉         | 985/10000 [05:13<41:55,  3.58it/s]
# Nan/Inf loss encountered
# loss: -5.125769534054366, mean log p_x -20.391137065754243:  10%|█         | 1000/10000 [05:18<47:27,  3.16it/s]
# loss: -3.3498325651664933, mean log p_x -24.30187525578861:  12%|█▏        | 1211/10000 [06:25<42:39,  3.43it/s]
# Nan/Inf loss encountered
# loss: 1.7115548262582285, mean log p_x -36.66653935073366:  15%|█▌        | 1500/10000 [07:57<47:25,  2.99it/s]
# loss: 1.7115548262582285, mean log p_x -36.66653935073366:  16%|█▌        | 1570/10000 [08:20<39:31,  3.55it/s]
# Nan/Inf loss encountered
# loss: 0.5934204124158646, mean log p_x -24.27634593618906:  20%|██        | 2000/10000 [10:19<37:30,  3.56it/s]
# loss: 4.049541072660741, mean log p_x -31.558417672192842:  21%|██▏       | 2142/10000 [10:58<32:17,  4.05it/s]
# Nan/Inf loss encountered
# loss: 3.5250966854453365, mean log p_x -26.180281573032868:  24%|██▍       | 2442/10000 [12:21<31:24,  4.01it/s]
# Nan/Inf loss encountered
# loss: 2.7236514116248625, mean log p_x -23.34619392660904:  25%|██▌       | 2500/10000 [12:37<35:09,  3.56it/s]
# loss: 2.0786504330016626, mean log p_x -20.595229886398325:  27%|██▋       | 2730/10000 [13:41<28:50,  4.20it/s]
# Nan/Inf loss encountered
# loss: 21.59638181833807, mean log p_x -50.93066293138706:  30%|███       | 3000/10000 [14:55<32:56,  3.54it/s]
# loss: 21.59638181833807, mean log p_x -50.93066293138706:  30%|███       | 3027/10000 [15:03<28:29,  4.08it/s]
# Nan/Inf loss encountered
# loss: 4.7711038099093805, mean log p_x -22.492077716046293:  31%|███▏      | 3141/10000 [15:35<28:11,  4.06it/s]
# Nan/Inf loss encountered
# loss: 18.27578437344755, mean log p_x -38.812015826931145:  35%|███▌      | 3500/10000 [17:14<30:45,  3.52it/s]
# loss: 7.724789033084621, mean log p_x -21.320435687663633:  39%|███▉      | 3923/10000 [19:11<25:29,  3.97it/s]
# Nan/Inf loss encountered
# loss: 11.031732248474071, mean log p_x -24.88777758523427:  40%|████      | 4000/10000 [19:32<25:57,  3.85it/s]
# loss: 11.031732248474071, mean log p_x -24.88777758523427:  40%|████      | 4019/10000 [19:38<24:12,  4.12it/s]
# Nan/Inf loss encountered
# loss: 5.85561856440326, mean log p_x -17.001927438757235:  43%|████▎     | 4303/10000 [20:56<28:13,  3.36it/s]
# Nan/Inf loss encountered
# loss: 5.85561856440326, mean log p_x -17.001927438757235:  44%|████▍     | 4377/10000 [21:16<22:49,  4.11it/s]
# Nan/Inf loss encountered
# loss: 12.915383770406734, mean log p_x -24.67920787207421:  45%|████▍     | 4467/10000 [21:41<24:38,  3.74it/s]
# Nan/Inf loss encountered
# loss: 11.225528931883815, mean log p_x -22.266087628770276:  45%|████▌     | 4500/10000 [21:50<23:19,  3.93it/s]
# loss: 12.484400280291384, mean log p_x -23.34329488488171:  47%|████▋     | 4654/10000 [22:33<21:46,  4.09it/s]
# Nan/Inf loss encountered
# loss: 10.510508899931992, mean log p_x -19.730453198487062:  49%|████▉     | 4932/10000 [23:50<20:04,  4.21it/s]
# Nan/Inf loss encountered
# loss: 10.510508899931992, mean log p_x -19.730453198487062:  50%|████▉     | 4955/10000 [23:56<20:44,  4.05it/s]
# Nan/Inf loss encountered
# loss: 10.658072012559124, mean log p_x -19.521543182382644:  50%|█████     | 5000/10000 [24:08<22:34,  3.69it/s]
# loss: 10.658072012559124, mean log p_x -19.521543182382644:  50%|█████     | 5010/10000 [24:11<22:38,  3.67it/s]
# Nan/Inf loss encountered
# loss: 21.096973290389506, mean log p_x -29.992537631940667:  54%|█████▍    | 5390/10000 [25:43<16:38,  4.62it/s]
# Nan/Inf loss encountered
# loss: 14.791719097340003, mean log p_x -23.681208750959925:  55%|█████▌    | 5500/10000 [26:10<17:17,  4.34it/s]
# loss: 9.699264737751083, mean log p_x -18.437244301990688:  56%|█████▌    | 5610/10000 [26:37<15:45,  4.64it/s]
# Nan/Inf loss encountered
# loss: 9.699264737751083, mean log p_x -18.437244301990688:  56%|█████▋    | 5626/10000 [26:40<16:32,  4.41it/s]
# Nan/Inf loss encountered
# loss: 10.746896690905583, mean log p_x -19.527426210701535:  58%|█████▊    | 5754/10000 [27:09<12:56,  5.47it/s]
# Nan/Inf loss encountered
# Nan/Inf loss encountered
# loss: 14.437982299950498, mean log p_x -23.2609766891446:  60%|██████    | 6000/10000 [28:04<15:36,  4.27it/s]
# loss: 12.656083186605155, mean log p_x -21.39196881952676:  61%|██████    | 6119/10000 [28:32<13:50,  4.67it/s]
# Nan/Inf loss encountered
# loss: 11.06927120975408, mean log p_x -19.681988641855497:  65%|██████▌   | 6500/10000 [29:59<13:18,  4.38it/s]
# loss: 9.871755783154116, mean log p_x -18.452402741059004:  70%|███████   | 7000/10000 [31:55<10:43,  4.66it/s]
# loss: 9.871755783154116, mean log p_x -18.452402741059004:  71%|███████   | 7051/10000 [32:07<10:20,  4.75it/s]
# Nan/Inf loss encountered
# loss: 90.62869747830662, mean log p_x -99.27787951627593:  74%|███████▍  | 7386/10000 [33:24<08:32,  5.10it/s]
# Nan/Inf loss encountered
# loss: 8.34054643652679, mean log p_x -16.878181692712804:  74%|███████▍  | 7418/10000 [33:31<08:35,  5.01it/s]
# Nan/Inf loss encountered
# loss: 7.69768815748523, mean log p_x -16.11807967856565:  75%|███████▌  | 7500/10000 [33:50<09:11,  4.53it/s]
# loss: 13.694319354169835, mean log p_x -22.18243036936343:  77%|███████▋  | 7669/10000 [34:29<08:15,  4.71it/s]
# Nan/Inf loss encountered
# loss: 6.243943845210298, mean log p_x -14.694272507540495:  79%|███████▊  | 7866/10000 [35:14<07:26,  4.78it/s]
# Nan/Inf loss encountered
# loss: 8.215560997833329, mean log p_x -16.650519006636543:  80%|████████  | 8000/10000 [35:44<07:29,  4.45it/s]
# loss: 8.215560997833329, mean log p_x -16.650519006636543:  81%|████████  | 8075/10000 [36:01<06:34,  4.87it/s]
# Nan/Inf loss encountered
# loss: 16.794730360156045, mean log p_x -25.254979635687686:  85%|████████▍ | 8459/10000 [37:26<04:50,  5.30it/s]
# Nan/Inf loss encountered
# loss: 16.794730360156045, mean log p_x -25.254979635687686:  85%|████████▍ | 8498/10000 [37:35<05:12,  4.81it/s]
# Nan/Inf loss encountered
# loss: 18.5400667930074, mean log p_x -26.85354010829485:  85%|████████▌ | 8500/10000 [37:35<05:31,  4.52it/s]
# loss: 8.753646132987132, mean log p_x -17.053562997426894:  88%|████████▊ | 8766/10000 [38:33<03:55,  5.23it/s]
# Nan/Inf loss encountered
# loss: 11.181930864240664, mean log p_x -19.533622001275756:  90%|█████████ | 9000/10000 [39:25<03:34,  4.67it/s]
# loss: 11.181930864240664, mean log p_x -19.533622001275756:  91%|█████████ | 9079/10000 [39:43<03:28,  4.42it/s]
# Nan/Inf loss encountered
# loss: 6.384117850968675, mean log p_x -14.597317983447873:  93%|█████████▎| 9280/10000 [40:28<02:18,  5.21it/s]
# Nan/Inf loss encountered
# loss: 9.802357118332935, mean log p_x -17.89389311484763:  95%|█████████▌| 9500/10000 [41:15<01:44,  4.78it/s]
# loss: 10.40197977804912, mean log p_x -18.579126467512754: 100%|██████████| 10000/10000 [43:05<00:00,  3.87it/s]
# NaN encountered in loss history
# NaN encountered in log_p_x history
# NaN encountered in log_q_x history
# NaN encountered in kl history
# NaN encountered in alpha_2_divergence history
# NaN encountered in importance_weights_var history
# NaN encountered in normalised_importance_weights_var history
# NaN encountered in effective_sample_size history
# estimate before training is 23.45107589978393
# estimate after training is nan
# effective sample size before is 0.012207940985827186
# effective sample size after train is nan
# variance in weights is nan
