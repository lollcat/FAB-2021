# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent.parent); os.chdir(set_path)

# %%
from TargetDistributions.DoubleWell import QuadrupleWellEnergy
import torch
from FittedModels.utils.plotting_utils import plot_sampling_info, plot_divergences
torch.manual_seed(5)
from ImportanceSampling.VanillaImportanceSampler import VanillaImportanceSampling
from FittedModels.train import LearntDistributionManager
from Utils.numerical_utils import quadratic_function as expectation_function
from FittedModels.Models.FlowModel import FlowModel
from FittedModels.utils.plotting_utils import plot_history
import matplotlib.pyplot as plt
from FittedModels.utils.plotting_utils import plot_samples_vs_contours_quadruple_well

# %%
def plotter(*args, **kwargs):
    # wrap plotting function like this so it displays during training
    plot_samples_vs_contours_quadruple_well(*args, **kwargs)
    plt.show()

# %%
target = QuadrupleWellEnergy(a=-0.5, b=-6)

# %% [markdown]
# # KL

# %%
torch.manual_seed(1)
torch.set_default_dtype(torch.float64)
# ******************* Parameters *******************
dim = 4
epochs = int(1e4)
n_samples_estimation = int(1e5)
batch_size = int(1e3)
lr = 1e-4
train_prior = False
weight_decay = 1e-5
clip_grad_norm = False
optimizer = "Adam"
flow_type = "RealNVP"
loss_type = "kl"
initial_flow_scaling = 1.5
n_flow_steps = 64
annealing = True
n_plots = 20

# %%
torch.manual_seed(0)  # 0
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=n_flow_steps,
                           scaling_factor=initial_flow_scaling, flow_type=flow_type)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type=loss_type,
                                   lr=lr, optimizer=optimizer, annealing=annealing, weight_decay=weight_decay)

plotter(tester)
plt.show()
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

if train_prior:
    history_prior = tester.train_prior(epochs=200, batch_size=batch_size, lr=5e-3)
    plot_history(history_prior)
    plt.show()
    plotter(tester)
    plt.show()
    expectation_prior_trained, info_prior = tester.estimate_expectation(n_samples_estimation, expectation_function)


history = tester.train(epochs, batch_size=batch_size, clip_grad_norm=clip_grad_norm, max_grad_norm=1,
                       intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
plot_history(history)
plt.show()
plot_divergences(history)
plt.show()
plot_sampling_info(history)
plt.show()

expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n"
      f"effective sample size before is {info_before['effective_sample_size'] / n_samples_estimation}\n"
      f"effective sample size after train is {info['effective_sample_size'] / n_samples_estimation}\n"
      f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

if train_prior:
    print(f"estimate after prior training is {expectation_prior_trained} \n"
        f"effective sample size trained prior is {info_prior['effective_sample_size'] / n_samples_estimation}\n")

plotter(tester, n_samples=1000)
plt.show()
# Out:
# loss: -7.293578136313299, mean log p_x -6.022012919318888:   0%|          | 0/10000 [00:00<?, ?it/s]
# loss: -7.834969992916332, mean log p_x -7.439471670102361:   5%|▌         | 500/10000 [02:43<51:19,  3.08it/s]
# loss: -8.027411029953338, mean log p_x 2.3294474324964725:  10%|█         | 1000/10000 [05:25<53:09,  2.82it/s]
# loss: -9.217149718661224, mean log p_x 8.160148747866677:  15%|█▌        | 1500/10000 [08:06<45:33,  3.11it/s]
# loss: -10.556586135958387, mean log p_x 11.148552774646884:  20%|██        | 2000/10000 [10:48<43:36,  3.06it/s]
# loss: -12.079041287322571, mean log p_x 13.316486818858712:  25%|██▌       | 2500/10000 [13:30<39:32,  3.16it/s]
# loss: -13.647972919029261, mean log p_x 14.796182048299217:  30%|███       | 3000/10000 [16:10<37:01,  3.15it/s]
# loss: -15.235673518006672, mean log p_x 15.634799354176051:  35%|███▌      | 3500/10000 [18:48<26:57,  4.02it/s]
# loss: -16.874791072150817, mean log p_x 16.245625760742428:  40%|████      | 4000/10000 [20:53<24:14,  4.12it/s]
# loss: -18.579079510781394, mean log p_x 16.64247847075681:  45%|████▌     | 4500/10000 [22:56<22:29,  4.08it/s]
# loss: -20.295600756408852, mean log p_x 17.087097347613007:  50%|█████     | 5000/10000 [25:01<18:58,  4.39it/s]
# loss: -20.294152951963802, mean log p_x 17.2715124207845:  55%|█████▌    | 5500/10000 [27:05<19:11,  3.91it/s]
# loss: -20.303914701976094, mean log p_x 17.187926776223335:  60%|██████    | 6000/10000 [29:08<15:48,  4.22it/s]
# loss: -20.340916422793548, mean log p_x 17.387762936639536:  65%|██████▌   | 6500/10000 [31:12<13:33,  4.30it/s]
# loss: -20.32822029901922, mean log p_x 17.280987265408775:  70%|███████   | 7000/10000 [33:16<12:45,  3.92it/s]
# loss: -20.377439078050354, mean log p_x 17.389247259207114:  75%|███████▌  | 7500/10000 [35:20<09:56,  4.19it/s]
# loss: -20.368410568233145, mean log p_x 17.290006335380856:  80%|████████  | 8000/10000 [36:56<06:13,  5.35it/s]
# loss: -20.354339034092256, mean log p_x 17.31088551262275:  85%|████████▌ | 8500/10000 [38:51<05:32,  4.52it/s]
# loss: -20.36397353846561, mean log p_x 17.313617847274493:  90%|█████████ | 9000/10000 [40:56<04:28,  3.72it/s]
# loss: -20.397209719430847, mean log p_x 17.353583902457018:  95%|█████████▌| 9500/10000 [43:01<02:11,  3.80it/s]
# loss: -20.422460908453743, mean log p_x 17.311323471200406: 100%|██████████| 10000/10000 [45:05<00:00,  3.70it/s]
# estimate before training is 23.45107589978393
# estimate after training is 23.32278124915885
# effective sample size before is 0.012207940985827186
# effective sample size after train is 0.13557012760963275
# variance in weights is 6.376320005131484e-10

# %% [markdown]
# # what if we change to alpha=2 and carry on training

# %%
tester.setup_loss(loss_type="DReG", alpha=2, k=1000, annealing=False, lr=5e-5) # keeping lr the same was unstable

# %%
history2 = tester.train(1000, batch_size=batch_size, clip_grad_norm=clip_grad_norm, max_grad_norm=1,
                       intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
# Out:
# loss: -20.460211747398255, mean log p_x 17.332888506797076:   0%|          | 0/1000 [00:00<?, ?it/s]
# loss: -19.96948248290777, mean log p_x 16.55333371746763:   5%|▌         | 50/1000 [00:13<03:47,  4.17it/s]
# loss: -20.469831448615437, mean log p_x 6.136615836187543:  10%|█         | 100/1000 [00:27<03:46,  3.97it/s]
# loss: -20.63912949475902, mean log p_x 15.551180301153702:  15%|█▍        | 149/1000 [00:41<04:11,  3.38it/s]
# Nan/Inf loss encountered
# loss: -14.965290368660812, mean log p_x 16.315685294031525:  15%|█▌        | 150/1000 [00:42<04:15,  3.33it/s]
# loss: -20.801496130680054, mean log p_x 16.32169486087228:  20%|██        | 200/1000 [00:59<04:10,  3.20it/s]
# loss: -20.81711721591927, mean log p_x 16.214361653310043:  25%|██▌       | 250/1000 [01:16<03:54,  3.20it/s]
# loss: -21.600904654317223, mean log p_x -2.0079923652807543:  30%|███       | 300/1000 [01:34<03:34,  3.27it/s]
# loss: -20.982024648994177, mean log p_x 15.873480114779568:  35%|███▌      | 350/1000 [01:51<03:31,  3.07it/s]
# loss: -20.082233481959726, mean log p_x 16.67286261802085:  40%|███▉      | 395/1000 [02:07<03:14,  3.10it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-18-39b8cf65cc4e> in <module>
# ----> 1 history2 = tester.train(1000, batch_size=batch_size, clip_grad_norm=clip_grad_norm, max_grad_norm=1,
#       2                        intermediate_plots=True, plotting_func=plotter, n_plots=n_plots)
#
# ~/ToyProblems/FittedModels/train.py in train(self, epochs, batch_size, extra_info, clip_grad_norm, max_grad_norm, clip_grad_max, max_grad_value, KPI_batch_size, intermediate_plots, plotting_func, n_plots, allow_ignore_nan_loss)
#     110             if clip_grad_norm is True:
#     111                 grad_norm = torch.nn.utils.clip_grad_norm_(self.learnt_sampling_dist.parameters(), max_grad_norm)
# --> 112             self.optimizer.step()
#     113             history["loss"].append(loss.item())
#     114             history["log_p_x"].append(torch.mean(log_p_x).item())
#
# /anaconda/envs/pytorch/lib/python3.8/site-packages/torch/optim/optimizer.py in wrapper(*args, **kwargs)
#      87                 profile_name = "Optimizer.step#{}.step".format(obj.__class__.__name__)
#      88                 with torch.autograd.profiler.record_function(profile_name):
# ---> 89                     return func(*args, **kwargs)
#      90             return wrapper
#      91
#
# /anaconda/envs/pytorch/lib/python3.8/site-packages/torch/autograd/grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# /anaconda/envs/pytorch/lib/python3.8/site-packages/torch/optim/adam.py in step(self, closure)
#      82                     grads.append(p.grad)
#      83
# ---> 84                     state = self.state[p]
#      85                     # Lazy state initialization
#      86                     if len(state) == 0:
#
# /anaconda/envs/pytorch/lib/python3.8/site-packages/torch/tensor.py in __hash__(self)
#     591         return iter(self.unbind(0))
#     592
# --> 593     def __hash__(self):
#     594         if has_torch_function_unary(self):
#     595             return handle_torch_function(Tensor.__hash__, (self,), self)
#
# KeyboardInterrupt:
