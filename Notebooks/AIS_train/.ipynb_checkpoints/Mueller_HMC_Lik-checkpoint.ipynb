# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent.parent); os.chdir(set_path)

# %%
# %load_ext autoreload
# %autoreload 2

# %%
# %reload_ext autoreload

# %%
from TargetDistributions.Mueller_potential import MuellerPotential
from FittedModels.utils.plotting_utils import plot_samples_vs_contours_many_well

# %%
from FittedModels.Models.FlowModel import FlowModel
from AIS_train.train_AIS import AIS_trainer
from ImportanceSampling.VanillaImportanceSampler import VanillaImportanceSampling
from FittedModels.utils.plotting_utils import plot_history, plot_distributions, plot_samples

import matplotlib.pyplot as plt
import torch
from Utils.plotting_utils import plot_func2D, plot_distribution
from Utils.numerical_utils import MC_estimate_true_expectation
from Utils.numerical_utils import quadratic_function as expectation_function
torch.set_default_dtype(torch.float64)

def plotter(*args, **kwargs):
    # wrap plotting function like this so it displays during training
    plot_samples_vs_contours_many_well(*args, **kwargs)
    plt.show()

# %%
dim = 2
target = MuellerPotential()

# %%
n_samples_expectation = int(1e4)
n_samples=int(1e4)

# %% [markdown]
# # Vanilla IS

# %%
learnt_sampler = FlowModel(x_dim=dim, scaling_factor=2.0, flow_type="RealNVP", n_flow_steps=60)
vanilla_IS = VanillaImportanceSampling(sampling_distribution=learnt_sampler, target_distribution=target)
with torch.no_grad():
    expectation_vanilla, info_dict_vanilla = \
    vanilla_IS.calculate_expectation(n_samples_expectation, expectation_function=expectation_function)
    print(f"ESS is {info_dict_vanilla['effective_sample_size']/n_samples_expectation}, \
          var is {torch.var(info_dict_vanilla['normalised_sampling_weights'])}")
# Out:
# ESS is 0.0005004851322789716,           var is 1.997261077993118e-05

# %% [markdown]
# # DReG likelihood

# %%
learnt_sampler = FlowModel(x_dim=dim, scaling_factor=2.0, flow_type="RealNVP", n_flow_steps=60)
tester = AIS_trainer(target, learnt_sampler, loss_type=False, n_distributions=20, n_steps_transition_operator=3,
                    step_size=1.0, transition_operator="HMC", learnt_dist_kwargs={"lr": 1e-4},
                     loss_type_2="alpha_2")

# %%
expectation_before, info_dict_before = tester.AIS_train.calculate_expectation(n_samples_expectation,
                                                                    expectation_function=expectation_function,
                                                                             batch_size=int(1e3))
print(info_dict_before['effective_sample_size'].item() / n_samples_expectation)
# Out:
# 0.00012147167203899485

# %%
plot_samples_vs_contours_many_well(tester, n_samples=1000,
                                      title=f"training epoch, samples from flow")
plot_samples_vs_contours_many_well(tester, n_samples=None,
                                      title=f"training epoch, samples from AIS",
                                      samples_q=info_dict_before["samples"])

# %%
history = tester.train(500, batch_size=int(1e3), intermediate_plots=True, n_plots=10, plotting_func=plotter)
# Out:
#   0%|                                                                                                                                                          | 0/500 [00:00<?, ?it/s]
# loss: 297.69153859647,   log_p_x_post_AIS -109.30773286246475, ESS 0.0010710910716360948:  10%|████▉                                            | 50/500 [2:14:41<21:32:28, 172.33s/it]
# loss: 297.20667255169235,   log_p_x_post_AIS -70.03234482430187, ESS 0.0022953277093888964:  20%|█████████▏                                    | 100/500 [4:56:32<22:06:17, 198.94s/it]
# loss: 296.35043840907144,   log_p_x_post_AIS 137.81721865873982, ESS 0.20860024894538914:  30%|██████████████▍                                 | 150/500 [7:44:41<19:45:26, 203.22s/it]
# loss: 296.05587466146403,   log_p_x_post_AIS 142.5713722167853, ESS 0.22399092816157617:  34%|████████████████▍                                | 168/500 [8:43:56<17:15:24, 187.12s/it]
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-16-7d48fc217cd8> in <module>
# ----> 1 history = tester.train(500, batch_size=int(5e3), intermediate_plots=True, n_plots=10, plotting_func=plotter)
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\AIS_train\train_AIS.py in train(self, epochs, batch_size, intermediate_plots, plotting_func, n_plots, KPI_batch_size, allow_ignore_nan_loss, clip_grad_norm, max_grad_norm)
#     108         pbar = tqdm(range(epochs))
#     109         for self.current_epoch in pbar:
# --> 110             x_samples, log_w = self.AIS_train.run(batch_size)
#     111             loss_1 = self.loss(log_w)
#     112             if self.use_2nd_loss:
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\AIS_train\AnnealedImportanceSampler.py in run(self, n_runs)
#      57         log_w += self.intermediate_unnormalised_log_prob(x_new, 1) - log_prob_p0
#      58         for j in range(1, self.n_distributions-1):
# ---> 59             x_new, log_w = self.perform_transition(x_new, log_w, j)
#      60         if "DReG" == self.loss_type:
#      61             self.sampling_distribution.set_requires_grad(True)
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\AIS_train\AnnealedImportanceSampler.py in perform_transition(self, x_new, log_w, j)
#      64     def perform_transition(self, x_new, log_w, j):
#      65         target_p_x = lambda x: self.intermediate_unnormalised_log_prob(x, j)
# ---> 66         x_new = self.transition_operator_class.run(x_new, target_p_x, j-1)
#      67         log_w = log_w + self.intermediate_unnormalised_log_prob(x_new, j + 1) - \
#      68                  self.intermediate_unnormalised_log_prob(x_new, j)
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\ImportanceSampling\SamplingAlgorithms\HamiltonianMonteCarlo.py in run(self, current_q, log_q_x, i)
#     124             return torch.autograd.grad(y, q, grad_outputs=torch.ones_like(y))[0]
#     125
# --> 126         current_q = self.HMC_func(U, current_q, grad_U, i)
#     127         return current_q
#     128
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\ImportanceSampling\SamplingAlgorithms\HamiltonianMonteCarlo.py in HMC_func(self, U, current_q, grad_U, i)
#      60             current_p = p
#      61             # make momentum half step
# ---> 62             p = p - epsilon * grad_U(q) / 2
#      63
#      64             # Now loop through position and momentum leapfrogs
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\ImportanceSampling\SamplingAlgorithms\HamiltonianMonteCarlo.py in grad_U(q)
#     121
#     122         def grad_U(q: torch.Tensor):
# --> 123             y = U(q)
#     124             return torch.autograd.grad(y, q, grad_outputs=torch.ones_like(y))[0]
#     125
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\ImportanceSampling\SamplingAlgorithms\HamiltonianMonteCarlo.py in U(x)
#     118         """
#     119         def U(x: torch.Tensor):
# --> 120             return - log_q_x(x)
#     121
#     122         def grad_U(q: torch.Tensor):
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\AIS_train\AnnealedImportanceSampler.py in <lambda>(x)
#      63
#      64     def perform_transition(self, x_new, log_w, j):
# ---> 65         target_p_x = lambda x: self.intermediate_unnormalised_log_prob(x, j)
#      66         x_new = self.transition_operator_class.run(x_new, target_p_x, j-1)
#      67         log_w = log_w + self.intermediate_unnormalised_log_prob(x_new, j + 1) - \
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\AIS_train\AnnealedImportanceSampler.py in intermediate_unnormalised_log_prob(self, x, j)
#      73         # j = 0 is the sampling distribution, j=N is the target distribution
#      74         beta = self.B_space[j]
# ---> 75         return (1-beta)*self.sampling_distribution.log_prob(x) + beta*self.target_distribution.log_prob(x)
#      76
#      77     def setup_n_distributions(self, n_distributions, distribution_spacing="geometric"):
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\FittedModels\Models\FlowModel.py in log_prob(self, x)
#     135
#     136     def log_prob(self, x):
# --> 137         x, log_prob = self.x_to_z(x)
#     138         return log_prob
#     139
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\FittedModels\Models\FlowModel.py in x_to_z(self, x)
#     100         log_prob += log_det
#     101         for flow_step in self.flow_blocks[::-1]:
# --> 102             x, log_determinant = flow_step.forward(x)
#     103             log_prob += log_determinant
#     104         prior_prob = self.prior.log_prob(x)
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\NormalisingFlow\RealNVP.py in forward(self, x)
#      41         x_d_plus_1_to_D = x[:, self.d:]
#      42         z_1_to_d = x_1_to_d
# ---> 43         st = self.MLP(x_1_to_d)
#      44         s, t = st.split(self.D_minus_d, dim=-1)
#      45         if self.use_exp:
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\NormalisingFlow\Nets\MLP.py in forward(self, x)
#      23     def forward(self, x):
#      24         for hidden_layer in self.hidden_layers:
# ---> 25             x = F.leaky_relu(hidden_layer(x))
#      26         return self.output_layer(x)
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\nn\modules\module.py in _call_impl(self, *input, **kwargs)
#     887             result = self._slow_forward(*input, **kwargs)
#     888         else:
# --> 889             result = self.forward(*input, **kwargs)
#     890         for hook in itertools.chain(
#     891                 _global_forward_hooks.values(),
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\nn\modules\linear.py in forward(self, input)
#      92
#      93     def forward(self, input: Tensor) -> Tensor:
# ---> 94         return F.linear(input, self.weight, self.bias)
#      95
#      96     def extra_repr(self) -> str:
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\nn\functional.py in linear(input, weight, bias)
#    1751     if has_torch_function_variadic(input, weight):
#    1752         return handle_torch_function(linear, (input, weight), input, weight, bias=bias)
# -> 1753     return torch._C._nn.linear(input, weight, bias)
#    1754
#    1755
#
# RuntimeError: [enforce fail at ..\c10\core\CPUAllocator.cpp:75] data. DefaultCPUAllocator: not enough memory: you tried to allocate 160000 bytes. Buy new RAM!

# %%
plot_history(history)

# %%
plot_history(dict([(key, history[key]) for key in ('loss', 'log_p_x_after_AIS', 'log_w', 'kl', 
                                               'alpha_2_divergence', 'log_q_AIS_x', 'ESS')]))

# %%
expectation, info_dict = tester.AIS_train.calculate_expectation(n_samples_expectation,
                                                                    expectation_function=expectation_function,
                                                                             batch_size=int(1e3))
print(info_dict['effective_sample_size'].item() / n_samples_expectation)

# %%
plot_samples_vs_contours_many_well(tester, n_samples=1000,
                                      title=f"training epoch, samples from flow")
plot_samples_vs_contours_many_well(tester, n_samples=None,
                                      title=f"training epoch, samples from AIS",
                                      samples_q=info_dict["samples"])
