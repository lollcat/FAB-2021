# %% [markdown]
# # Imports and define expectation func

# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent); os.chdir(set_path)

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib as mpl
from FittedModels.utils import plot_distributions, plot_samples, plot_sampling_info, plot_divergences
torch.manual_seed(5)
from ImportanceSampling.VanillaImportanceSampler import VanillaImportanceSampling
from TargetDistributions.MoG import MoG
from TargetDistributions.Guassian_FullCov import Guassian_FullCov
from FittedModels.Models.DiagonalGaussian import DiagonalGaussian
from FittedModels.utils import plot_distributions
from FittedModels.train import LearntDistributionManager
from Utils import plot_func2D, MC_estimate_true_expectation, plot_distribution, expectation_function
from FittedModels.Models.FlowModel import FlowModel
from FittedModels.experimental.train_AIS import AIS_trainer
from FittedModels.utils import plot_history
import matplotlib.pyplot as plt
from TargetDistributions.MoG import MoG
from TargetDistributions.MoG import custom_MoG

# %%
expectation_func_fig = plot_func2D(expectation_function, n_points=200, range=15)

# %% [markdown]
# # Lumpy Flow Target Distribution

# %%
torch.manual_seed(0) # 0 breaks it within 1000 epochs
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=10, min_cov=0, loc_scaling=3)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
torch.manual_seed(1)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, scaling_factor=4.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(5000, batch_size=int(1e2))
# Out:
# loss: -23.607324600219727, mean log p_x -98.92411804199219: 100%|██████████████████████████████████████████████████████████████████████████████████| 5000/5000 [02:08<00:00, 38.90it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 17.670400619506836
# estimate before training is 17.89559555053711
# estimate after training is 86.4417724609375
# effective sample size before is 1301.0831298828125 out of 10000
# effective sample size after train is 3.9085044860839844  out of 10000
# variance in weights is 2.5577794076525606e-05

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
hist_plot = plot_history(history)
# Out:
# NaN encountered in alpha_2_divergence_over_p history
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %% [markdown]
# # Increase Batch Size
# Makes it happy

# %%
torch.manual_seed(0) # 0 breaks it within 1000 epochs
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=10, min_cov=0, loc_scaling=3)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
torch.manual_seed(1)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, scaling_factor=4.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(6000, batch_size=int(1e3))
# Out:
# loss: -0.42322384136738755, mean log p_x -4.217279628758801: 100%|█████████████████████████████████████████████████████████████████████████████████| 3000/3000 [02:46<00:00, 18.04it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 14.437952185024466
# estimate before training is 14.14882544137432
# estimate after training is 14.203317628810618
# effective sample size before is 2029.7525332601624 out of 10000
# effective sample size after train is 7420.063683795858  out of 10000
# variance in weights is 3.4773210117756825e-09

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
fig_hist = plot_history(history)

# %% [markdown]
# # Increase the precision

# %%
torch.set_default_dtype(torch.float64)

# %%
torch.manual_seed(3)
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=10, min_cov=0, loc_scaling=3)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
torch.manual_seed(1)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, scaling_factor=2.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(2000, batch_size=int(1e2))
# Out:
# loss: -0.47191611859348587, mean log p_x -8.429582928141528: 100%|█████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:35<00:00, 28.32it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 14.502694662257596
# estimate before training is 15.93587103190501
# estimate after training is 15.14840991105726
# effective sample size before is 1430.6186813042616 out of 10000
# effective sample size after train is 59.14718436114416  out of 10000
# variance in weights is 1.6808656418258957e-06

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)
# Out:
# NaN encountered in alpha_2_divergence_over_p history
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %% [markdown]
# # Gradient Norm Clip
# This helps!

# %%
torch.manual_seed(0) # 0 breaks it within 1000 epochs
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=10, min_cov=0, loc_scaling=3)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
torch.manual_seed(1)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, scaling_factor=4.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(20000, batch_size=int(1e2), clip_grad=True, max_grad_norm=1)
# Out:
# loss: -0.3621882200241089, mean log p_x -5.50814962387085: 100%|█████████████████████████████████████████████████████████████████████████████████| 20000/20000 [08:12<00:00, 40.62it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 17.670400619506836
# estimate before training is 17.89559555053711
# estimate after training is 17.845096588134766
# effective sample size before is 1301.0831298828125 out of 10000
# effective sample size after train is 4971.890625  out of 10000
# variance in weights is 1.0114085569057352e-08

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
hist_plot = plot_history(history)

# %% [markdown]
# # Lower the learning rate
# Helps, but slows down learning, and seems like it makes the algorithm more likely to stay overly smooth

# %%
torch.manual_seed(1)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, scaling_factor=2.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG", lr=1e-4)
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(40000, batch_size=int(1e2))
# Out:
# loss: -1.196240112251438, mean log p_x -7.829589775170722: 100%|█████████████████████████████████████████████████████████████████████████████████| 40000/40000 [20:01<00:00, 33.28it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 14.502694662257596
# estimate before training is 15.93587103190501
# estimate after training is 15.257120148728642
# effective sample size before is 1430.6186813042616 out of 10000
# effective sample size after train is 2104.2796883087826  out of 10000
# variance in weights is 3.7525952498424507e-08

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
hist_fig = plot_history(history)

# %% [markdown]
# # Combo

# %%
torch.set_default_dtype(torch.float64)

# %%
torch.manual_seed(0) # 0 breaks it within 1000 epochs
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=10, min_cov=0, loc_scaling=3)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
torch.manual_seed(1)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=5, scaling_factor=4.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
learnt_sampler.sample((1,)).dtype, target.log_prob(learnt_sampler.sample((1,))).dtype
# Out:
# (torch.float64, torch.float64)

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(10000, batch_size=int(1e3), clip_grad=True, max_grad_norm=1)
# Out:
# loss: -0.31956645673846457, mean log p_x -4.307212972999804:  22%|█████████████████▍                                                              | 2174/10000 [03:56<15:39,  8.33it/s]
# loss: -0.31956645673846457, mean log p_x -4.307212972999804:  22%|█████████████████▍                                                              | 2174/10000 [03:57<14:14,  9.16it/s]
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# <ipython-input-58-ee92c186be82> in <module>
# ----> 1 history = tester.train(10000, batch_size=int(1e3), clip_grad=True, max_grad_norm=1)
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\FittedModels\train.py in train(self, epochs, batch_size, extra_info, clip_grad, max_grad_norm)
#      61             log_p_x = self.target_dist.log_prob(x_samples)
#      62             loss = self.loss(x_samples, log_q_x, log_p_x)
# ---> 63             self.check_infs_and_NaNs(epoch, log_p_x, log_q_x, loss, history)
#      64             loss.backward()
#      65             if clip_grad is True:
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\FittedModels\train.py in check_infs_and_NaNs(self, epoch, log_p_x, log_q_x, loss, history)
#     176             plot_history(history)
#     177             plt.show()
# --> 178             raise Exception(f"NaN loss encountered on epoch {epoch}")
#     179
#     180
#
# Exception: NaN loss encountered on epoch 2174

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 14.437952185024466
# estimate before training is 14.362631213088976
# estimate after training is 14.559857994042721
# effective sample size before is 1869.3233719942116 out of 10000
# effective sample size after train is 7693.145555508995  out of 10000
# variance in weights is 2.9988840538110034e-09

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
hist_plot = plot_history(history)

# %% [markdown]
# # New Section
