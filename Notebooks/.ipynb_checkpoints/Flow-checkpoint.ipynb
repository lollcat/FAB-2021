# %% [markdown]
# # Imports and define expectation func

# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent); os.chdir(set_path)

# %%
import torch
import matplotlib.pyplot as plt
import matplotlib as mpl
from FittedModels.utils import plot_distributions, plot_samples, plot_sampling_info, plot_divergences
torch.manual_seed(5)
from ImportanceSampling.VanillaImportanceSampler import VanillaImportanceSampling
from TargetDistributions.MoG import MoG
from TargetDistributions.Guassian_FullCov import Guassian_FullCov
from FittedModels.Models.DiagonalGaussian import DiagonalGaussian
from FittedModels.utils import plot_distributions
from FittedModels.train import LearntDistributionManager
from Utils import plot_func2D, MC_estimate_true_expectation, plot_distribution, expectation_function
from FittedModels.Models.FlowModel import FlowModel
from FittedModels.experimental.train_AIS import AIS_trainer
from FittedModels.utils import plot_history
import matplotlib.pyplot as plt
from TargetDistributions.MoG import MoG
from TargetDistributions.MoG import custom_MoG

# %%
#mpl.rcParams['figure.dpi'] = 100

# %%
expectation_func_fig = plot_func2D(expectation_function, n_points=200, range=15)

# %% [markdown]
# # Let's start with Guassian Problem

# %% [markdown]
# Shows basic flow model is working (IAF clearly very expressive), if we use a friendly gaussian relatively well suited to the pior <br>
# We see here that KL and DReG get very similar results

# %% [markdown]
# ## Setup

# %%
torch.manual_seed(2)
dim = 2
n_samples_estimation = int(1e4)
target = Guassian_FullCov(dim=dim, scale_covariance=1)
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
fig = plot_distribution(target)

# %% [markdown]
# ## Flow with DReG - well suited prior

# %%
epochs = 1000
batch_size = 100

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, flow_type="RealNVP")
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_fig_before = plot_samples(tester)

# %%
fig_before_train = plot_distributions(tester)

# %%
history = tester.train(epochs, batch_size=batch_size)
# Out:
# loss: -0.002217274159193039, mean log p_x -3.8659722805023193: 100%|███████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:13<00:00, 75.93it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 8.210801124572754
# estimate before training is 7.371506214141846
# estimate after training is 8.111334800720215
# effective sample size before is 250.00527954101562 out of 10000
# effective sample size after train is 9990.80078125  out of 10000
# variance in weights is 9.207455110848972e-12

# %%
fig_after_train = plot_distributions(tester)

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
hist_fig = plot_history(history)

# %% [markdown]
# ## Flow with MC alpha div
# does terribly

# %%
epochs = 100
batch_size = 100

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="alpha_MC", alpha=2)
expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_fig_before = plot_samples(tester)

# %%
fig_before_train = plot_distributions(tester)

# %%
history = tester.train(epochs, batch_size=batch_size)
# Out:
# loss: -281115680.0, mean log p_x -140557856.0:  66%|████████████████████████████████████████████████████████████████▋                                 | 66/100 [00:03<00:01, 19.82it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# found a NaN and overwrote it during flow gradient calculation
# found a NaN and overwrote it during flow gradient calculation
# found a NaN and overwrote it during flow gradient calculation
# NaN/-inf loss encountered in log_p_x
# loss: -800000003014656.0, mean log p_x -inf:  69%|█████████████████████████████████████████████████████████████████████                               | 69/100 [00:03<00:01, 19.03it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -535195673427968.0, mean log p_x -inf:  76%|████████████████████████████████████████████████████████████████████████████                        | 76/100 [00:04<00:01, 19.15it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -535195673427968.0, mean log p_x -inf:  78%|██████████████████████████████████████████████████████████████████████████████                      | 78/100 [00:04<00:01, 19.36it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -700018063310848.0, mean log p_x -inf:  83%|███████████████████████████████████████████████████████████████████████████████████                 | 83/100 [00:04<00:00, 19.88it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -1279680674004992.0, mean log p_x -inf:  89%|████████████████████████████████████████████████████████████████████████████████████████           | 89/100 [00:04<00:00, 20.44it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -1139738157252608.0, mean log p_x -inf:  92%|███████████████████████████████████████████████████████████████████████████████████████████        | 92/100 [00:04<00:00, 19.55it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -1000002537127936.0, mean log p_x -inf:  96%|███████████████████████████████████████████████████████████████████████████████████████████████    | 96/100 [00:05<00:00, 18.09it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# loss: -1000002537127936.0, mean log p_x -inf: 100%|██████████████████████████████████████████████████████████████████████████████████████████████████| 100/100 [00:05<00:00, 18.97it/s]
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x
# NaN/-inf loss encountered in log_p_x

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-34-2f0677bdda1a> in <module>
# ----> 1 expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
#       2
#       3 print(f"True expectation estimate is {true_expectation} \n"
#       4     f"estimate before training is {expectation_before} \n"
#       5       f"estimate after training is {expectation} \n"
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\FittedModels\train.py in estimate_expectation(self, n_samples, expectation_function)
#     185     def estimate_expectation(self, n_samples=int(1e4), expectation_function=lambda x: torch.sum(x, dim=-1)):
#     186         importance_sampler = self.importance_sampler(self.learnt_sampling_dist, self.target_dist)
# --> 187         expectation, normalised_sampling_weights = importance_sampler.calculate_expectation(n_samples, expectation_function)
#     188         return expectation, normalised_sampling_weights
#     189
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\ImportanceSampling\VanillaImportanceSampler.py in calculate_expectation(self, n_samples, expectation_function)
#      15     def calculate_expectation(self, n_samples:int=1000, expectation_function=lambda x: torch.sum(x, dim=-1))\
#      16             -> (torch.tensor, dict):
# ---> 17         x_samples, normalised_sampling_weights = self.generate_samples_and_weights(n_samples=n_samples)
#      18         expectation_func_x = expectation_function(x_samples)
#      19         expectation = torch.sum(normalised_sampling_weights*expectation_func_x)
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\autograd\grad_mode.py in decorate_context(*args, **kwargs)
#      25         def decorate_context(*args, **kwargs):
#      26             with self.__class__():
# ---> 27                 return func(*args, **kwargs)
#      28         return cast(F, decorate_context)
#      29
#
# D:\Documents\Work\2020\Cambridge MLMI\MLMI\Thesis\CODE\ToyProblems\ImportanceSampling\VanillaImportanceSampler.py in generate_samples_and_weights(self, n_samples)
#      26     def generate_samples_and_weights(self, n_samples:int=1000):
#      27         x_samples, log_q_x = self.sampling_distribution(n_samples)
# ---> 28         log_p_x = self.target_distribution.log_prob(x_samples)
#      29         if True in torch.isnan(log_p_x) or True in torch.isinf(log_p_x):
#      30             print("Nan encountered in importance weights")
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\distributions\multivariate_normal.py in log_prob(self, value)
#     206     def log_prob(self, value):
#     207         if self._validate_args:
# --> 208             self._validate_sample(value)
#     209         diff = value - self.loc
#     210         M = _batch_mahalanobis(self._unbroadcasted_scale_tril, diff)
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\distributions\distribution.py in _validate_sample(self, value)
#     275         assert support is not None
#     276         if not support.check(value).all():
# --> 277             raise ValueError('The value argument must be within the support')
#     278
#     279     def _get_checked_instance(self, cls, _instance=None):
#
# ValueError: The value argument must be within the support

# %%
fig_after_train = plot_distributions(tester)

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)

# %% [markdown]
# ## Flow with KL - nice prior

# %%
epochs = 1000
batch_size = 100

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="kl")
expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_fig_before = plot_samples(tester)

# %%
fig_before_train = plot_distributions(tester)

# %%
history = tester.train(epochs, batch_size=batch_size)
# Out:
# loss: -0.0015680146170780063, mean log p_x -3.7283687591552734: 100%|██████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:15<00:00, 63.72it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 8.210801124572754
# estimate before training is 10.93683910369873
# estimate after training is 8.27730655670166
# effective sample size before is 250.00527954101562 out of 10000
# effective sample size after train is 9778.447265625  out of 10000
# variance in weights is 2.2659740750441415e-10

# %%
fig_after_train = plot_distributions(tester)

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)
# Out:
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %% [markdown]
# ## Setup nastier prior

# %%
torch.manual_seed(2)
dim = 2
n_samples_estimation = int(1e4)
target = Guassian_FullCov(dim=dim, scale_covariance=0.01)
fig = plot_distribution(target)

# %% [markdown]
# ## Flow with DReG - poorly suited prior

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, prior_scaling=1)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
#expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester)

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(epochs, batch_size=batch_size)

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds = [[-2, 2],[-2, 2]])

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)

# %% [markdown]
# ## Flow with kl - poorly suited prior

# %%
torch.manual_seed(0) 
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="kl")
expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
dist_before = plot_distributions(tester)
# below plot if we want to look in specific zone
#flow_only = plot_distribution(tester.learnt_sampling_dist, bounds = [[-100, 0],[-10, 10]], n_points=200)

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(epochs, batch_size=batch_size)

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)

# %% [markdown]
# ## Let's compare to our standard diagonal guassian case to show that flows help

# %%
learnt_sampler = DiagonalGaussian(dim=dim)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
fig_before = fig_before_train = plot_distributions(tester)
expectation_before, sampling_weights_before = tester.estimate_expectation()

# %%
history = tester.train(epochs)
expectation, info = tester.estimate_expectation(n_samples_estimation)
true_expectation = torch.sum(tester.target_dist.mean)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
fig_after_train = plot_distributions(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %% [markdown]
# # Easy MoG

# %% [markdown]
# ## Setup

# %%
torch.manual_seed(6)
epochs = 500
dim = 2
n_samples_estimation = int(1e4)
#target = MoG(dim=dim, n_mixes=2, min_cov=0.01, loc_scaling=0.8)
target = custom_MoG(dim=dim, cov_scaling=0.3)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))
true_expectation
# Out:
# tensor(4.5998)

# %% [markdown]
# ## DReG

# %% [markdown]
# ### Let's train for a bit

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim , n_flow_steps=3) #, flow_type="RealNVP")
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG", k=None)
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_before = plot_samples(tester, n_samples=int(1e4))

# %%
history = tester.train(1000, batch_size=int(1e3))
# Out:
# loss: -0.06405559182167053, mean log p_x -2.367068290710449: 100%|█████████████████████████████████████████████████████████████████████████████████| 1000/1000 [00:53<00:00, 18.66it/s]

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 4.599788188934326
# estimate before training is 4.562889099121094
# estimate after training is 4.630249500274658
# effective sample size before is 1849.11865234375 out of 10000
# effective sample size after train is 9568.1533203125  out of 10000
# variance in weights is 4.5138226489882527e-10

# %%
plot_history(history)
# Out:
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %% [markdown]
# ### Train more and it carries on getting better

# %%
history = tester.train(5000, batch_size=int(1e3))
# Out:
# loss: -0.022616911679506302, mean log p_x -2.3413875102996826: 100%|███████████████████████████████████████████████████████████████████████████████| 5000/5000 [04:24<00:00, 18.93it/s]

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 4.599788188934326
# estimate before training is 4.562889099121094
# estimate after training is 4.6196064949035645
# effective sample size before is 1849.11865234375 out of 10000
# effective sample size after train is 9804.2880859375  out of 10000
# variance in weights is 1.9963977693215895e-10

# %%
plot_history(history)
# Out:
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %% [markdown]
# ### With smaller batch size

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim , n_flow_steps=3) #, flow_type="RealNVP")
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG", k=None)
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
history = tester.train(10000, batch_size=int(1e2))
# Out:
# loss: -0.019243083894252777, mean log p_x -2.462040424346924: 100%|████████████████████████████████████████████████████████████████████████████████| 2000/2000 [00:55<00:00, 35.86it/s]

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 4.599788188934326
# estimate before training is 4.562889099121094
# estimate after training is 4.612569808959961
# effective sample size before is 1849.11865234375 out of 10000
# effective sample size after train is 9593.59375  out of 10000
# variance in weights is 4.2366982144770304e-10

# %%
plot_history(history)
# Out:
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %% [markdown]
# ## kl

# %%
torch.manual_seed(0) # 0
learnt_sampler = FlowModel(x_dim=dim , n_flow_steps=3) #, flow_type="RealNVP")
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="kl") 
expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_before = plot_samples(tester)

# %%
fig_before_train = plot_distributions(tester)

# %%
history = tester.train(1000, batch_size=100) # epochs 1000

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %%
samples_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)

# %% [markdown]
# ## DReG with alpha = 0.05

# %%
torch.manual_seed(0) # 1 we get a pathological case
learnt_sampler = FlowModel(x_dim=dim , n_flow_steps=5) #  , flow_type="RealNVP"
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG", alpha=0.05) # "kl"

# %%
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_before = plot_samples(tester)

# %%
fig_before_train = plot_distributions(tester)

# %%
history = tester.train(10000, batch_size=100)

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-10, 5], [-6, 4]])

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %%
plot_history(history)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %% [markdown]
# # Steep Difficult MoG

# %% [markdown]
# ## Setup

# %%
torch.manual_seed(1)
epochs = 500
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=2, min_cov=1, loc_scaling=10)
fig = plot_distribution(target, bounds=[[-20, 20], [-20, 20]])

# %% [markdown]
# ## DReG

# %%
torch.manual_seed(1) 
learnt_sampler = FlowModel(x_dim=dim , n_flow_steps=3, scaling_factor=5) #, flow_type="RealNVP"
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")#, alpha=0.05) # "kl"

# %%
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_before = plot_samples(tester, n_samples=int(1e5))

# %%
history = tester.train(1000, batch_size=int(1e3))

# %%
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)

# %% [markdown]
# ### But if we train for longer

# %%
history = tester.train(1000, batch_size=int(1e3))

# %%
samples_fig_after = plot_samples(tester)

# %%
plot_history(history)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
#fig_after_train = plot_distributions(tester)

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} \n"
     f"effective sample size after train is {info['effective_sample_size']} \n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %% [markdown]
# ## kl

# %%
torch.manual_seed(1) # 0
learnt_sampler = FlowModel(x_dim=dim , n_flow_steps=3) # , flow_type="RealNVP"
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="kl") 
expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
samples_before = plot_samples(tester)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-20, 20], [-20, 20]])

# %%
history = tester.train(1000, batch_size=100) # epochs 1000

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")

# %%
samples_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, )

# %%
plot_history(history)

# %% [markdown]
# #  Lumpy many MoG

# %% [markdown]
# ### Let's go

# %%
torch.manual_seed(0)
dim = 2
n_samples_estimation = int(1e4)
target = MoG(dim=dim, n_mixes=10, min_cov=0, loc_scaling=1.5)
fig = plot_distribution(target, bounds=[[-5, 5], [-5, 5]])
true_expectation = MC_estimate_true_expectation(target, expectation_function, int(1e6))

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3, scaling_factor=2.0)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="DReG")
expectation_before, info_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(1000, batch_size=int(1e3))
# Out:
# loss: -0.5051462054252625, mean log p_x -3.8828060626983643: 100%|█████████████████████████████████████████████████████████████████████████████████| 1000/1000 [01:00<00:00, 16.47it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 5.078380584716797
# estimate before training is 5.149537563323975
# estimate after training is 5.073213577270508
# effective sample size before is 3131.1015625 out of 10000
# effective sample size after train is 6745.6845703125  out of 10000
# variance in weights is 4.824771693279217e-09

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]], n_points=200)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)
# Out:
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %% [markdown]
# ### Let's train a bit more

# %%
history = tester.train(2000, batch_size=int(1e3))
# Out:
# loss: -0.2856842875480652, mean log p_x -4.196994304656982: 100%|██████████████████████████████████████████████████████████████████████████████████| 2000/2000 [01:57<00:00, 17.02it/s]

# %%
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# True expectation estimate is 5.078380584716797
# estimate before training is 5.149537563323975
# estimate after training is 3.0400664806365967
# effective sample size before is 3131.1015625 out of 10000
# effective sample size after train is 4762.78173828125  out of 10000
# variance in weights is 1.0997224464404098e-08

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]], n_points=200)

# %%
plot_divergences(history)

# %%
plot_sampling_info(history)

# %%
plot_history(history)
# Out:
# NaN encountered in alpha_2_divergence_over_p history
# (<Figure size 432x720 with 9 Axes>,
#  array([<AxesSubplot:title={'center':'loss'}>,
#         <AxesSubplot:title={'center':'log_p_x'}>,
#         <AxesSubplot:title={'center':'log_q_x'}>,
#         <AxesSubplot:title={'center':'kl'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence'}>,
#         <AxesSubplot:title={'center':'alpha_2_divergence_over_p'}>,
#         <AxesSubplot:title={'center':'importance_weights_var'}>,
#         <AxesSubplot:title={'center':'normalised_importance_weights_var'}>,
#         <AxesSubplot:title={'center':'effective_sample_size'}>],
#        dtype=object))

# %% [markdown]
# ### KL

# %%
torch.manual_seed(0)
learnt_sampler = FlowModel(x_dim=dim, n_flow_steps=3)
tester = LearntDistributionManager(target, learnt_sampler, VanillaImportanceSampling, loss_type="kl")
#expectation_before, sampling_weights_before = tester.estimate_expectation(n_samples_estimation, expectation_function)

# %%
fig_before_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
samples_fig_before = plot_samples(tester)

# %%
history = tester.train(10000, batch_size=100)
expectation, info = tester.estimate_expectation(n_samples_estimation, expectation_function)
# Out:
# loss: 0.14024598896503448, mean log p_x -3.444486141204834: 100%|████████████████████████████████████████████████████████████████████████████████| 10000/10000 [01:58<00:00, 84.36it/s]

# %%
print(f"True expectation estimate is {true_expectation} \n"
    f"estimate before training is {expectation_before} \n"
      f"estimate after training is {expectation} \n" 
     f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
     f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
     f"variance in weights is {torch.var(info['normalised_sampling_weights'])}")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-11049398b84a> in <module>
# ----> 1 print(f"True expectation estimate is {true_expectation} \n"
#       2     f"estimate before training is {expectation_before} \n"
#       3       f"estimate after training is {expectation} \n"
#       4      f"effective sample size before is {info_before['effective_sample_size']} out of {n_samples_estimation}\n"
#       5      f"effective sample size after train is {info['effective_sample_size']}  out of {n_samples_estimation}\n"
#
# NameError: name 'expectation_before' is not defined

# %%
samples_fig_after = plot_samples(tester)

# %%
fig_after_train = plot_distributions(tester, bounds=[[-5, 5], [-5, 5]])

# %%
plot_history(history)

# %%
fig_before = plot_distributions(tester)

# %% [markdown]
# # New Section
