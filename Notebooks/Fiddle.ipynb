# %%
from pathlib import Path
import os
cwd_path = Path.cwd(); set_path = str(cwd_path.parent); os.chdir(set_path)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
from NormalisingFlow.IAF import IAF

class TestClass(nn.Module):
    def __init__(self):
        super(TestClass, self).__init__()
        self.flow_blocks = nn.ModuleList([])
        #self.flow_blocks.append(IAF(2))

# %%
y = TestClass()
x = copy.deepcopy(y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-26-165a5456ac40> in <module>
#       1 y = TestClass()
# ----> 2 x = copy.deepcopy(y)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\tensor.py in __deepcopy__(self, memo)
#      53             return handle_torch_function(Tensor.__deepcopy__, (self,), self, memo)
#      54         if not self.is_leaf:
# ---> 55             raise RuntimeError("Only Tensors created explicitly by the user "
#      56                                "(graph leaves) support the deepcopy protocol at the moment")
#      57         if id(self) in memo:
#
# RuntimeError: Only Tensors created explicitly by the user (graph leaves) support the deepcopy protocol at the moment

# %%
from NormalisingFlow.IAF import IAF
flow = IAF(2)
flow_copy = copy.deepcopy(IAF)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F


class FlowModel(nn.Module):
    """
    here forward goes from z -> x, and backwards from x-> z, could maybe re-order
    we are also assuming that we are only interested in p(x), so return this for both forwards and backwards,
    we could add methods for p(z) if this comes into play
    """
    def __init__(self, x_dim, flow_type="IAF", n_flow_steps=3, prior_scaling=1.0):
        #self.dim = x_dim
        super(FlowModel, self).__init__()
        #self.prior_scaling = torch.tensor([prior_scaling])
        #self.prior = torch.distributions.MultivariateNormal(loc=torch.zeros(x_dim),
                                                                covariance_matrix=torch.eye(x_dim)*self.prior_scaling)
        if flow_type == "IAF":
            from NormalisingFlow.IAF import IAF
            flow = IAF
            self.flow_blocks = nn.ModuleList([])
            for i in range(n_flow_steps):
                self.flow_blocks.append(flow(x_dim))
        elif flow_type == "RealNVP":
            from NormalisingFlow.RealNVP import RealNVP
            flow = RealNVP
            self.flow_blocks = nn.ModuleList([])
            for i in range(n_flow_steps):
                reversed = i % 2 == 0
                self.flow_blocks.append(flow(x_dim, reversed=reversed))
        else:
            raise Exception("incorrectly specified flow")
# Out:
#   File "<ipython-input-14-cf5eb3774b87>", line 17
#     covariance_matrix=torch.eye(x_dim)*self.prior_scaling)
#     ^
# IndentationError: unexpected indent

# %%
import copy

# %%
y = FlowModel(2)
x = copy.deepcopy(y)

# %%
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# <ipython-input-17-190cf9ebe0e3> in <module>
# ----> 1 x = copy.deepcopy(y)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     294             for key, value in dictiter:
#     295                 key = deepcopy(key, memo)
# --> 296                 value = deepcopy(value, memo)
#     297                 y[key] = value
#     298         else:
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     170                     y = x
#     171                 else:
# --> 172                     y = _reconstruct(x, memo, *rv)
#     173
#     174     # If is its own copy, don't memoize.
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _reconstruct(x, memo, func, args, state, listiter, dictiter, deepcopy)
#     268     if state is not None:
#     269         if deep:
# --> 270             state = deepcopy(state, memo)
#     271         if hasattr(y, '__setstate__'):
#     272             y.__setstate__(state)
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     144     copier = _deepcopy_dispatch.get(cls)
#     145     if copier is not None:
# --> 146         y = copier(x, memo)
#     147     else:
#     148         if issubclass(cls, type):
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in _deepcopy_dict(x, memo, deepcopy)
#     228     memo[id(x)] = y
#     229     for key, value in x.items():
# --> 230         y[deepcopy(key, memo)] = deepcopy(value, memo)
#     231     return y
#     232 d[dict] = _deepcopy_dict
#
# ~\miniconda3\envs\Pytorch\lib\copy.py in deepcopy(x, memo, _nil)
#     151             copier = getattr(x, "__deepcopy__", None)
#     152             if copier is not None:
# --> 153                 y = copier(memo)
#     154             else:
#     155                 reductor = dispatch_table.get(cls)
#
# ~\miniconda3\envs\Pytorch\lib\site-packages\torch\tensor.py in __deepcopy__(self, memo)
#      53             return handle_torch_function(Tensor.__deepcopy__, (self,), self, memo)
#      54         if not self.is_leaf:
# ---> 55             raise RuntimeError("Only Tensors created explicitly by the user "
#      56                                "(graph leaves) support the deepcopy protocol at the moment")
#      57         if id(self) in memo:
#
# RuntimeError: Only Tensors created explicitly by the user (graph leaves) support the deepcopy protocol at the moment
